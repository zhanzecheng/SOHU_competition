# %% [markdown]
# # 模型预测&训练
# 这一部分是模型的训练和预测，我们使用到的模型可以分为两类
#
# ## 单模型
# ### 深度学习模型
# 我们联合了新闻文本和图片上的文本信息来构建模型，基本框架如下图所示
# ![img](../img/example.png)
#
# ### 机器学习模型
#
# * 输入特征为TFIDF+SVD、Basic Features等
# * 这里OCR出来的结果和新闻文本是做简单拼接的方式
# * 模型有：xgboost、catboost、lightGBM、DNN
#
#
# | 模型或方法          | 得分F1-measure                                   |
# | ----------- | ----------------------------------------
# | catboost     | 0.611                                  |
# | xgboost         | 0.621                                   |
# | lightgbm      | 0.625                                   |
# | dnn         | 0.621|
# | textCNN  |0.617|
# | capsule      |0.625|
# | covlstm    |0.630|
# | dpcnn    |0.626|
# | lstm+gru    |0.635|
# | lstm+gru+attention    |0.640|

# %%
# 导入必要的包
import pickle
import numpy as np
import os
from config import Config
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing import sequence
from keras.utils import np_utils
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
config = Config()
# 读取词对应的id
with open(config.ITEM_TO_ID, 'rb') as f:
    item_to_id = pickle.load(f)
# 取最后一位作为UNK表识
UNK = len(item_to_id)

# %% [markdown]
# #### 让我们来导入一下传统模型【xgboost、catboost、lightgbm等】的训练数据

# %%
def static_data_prepare():
    """

    :return:
    """
    train_y = []

    with open(config.TRAIN_X, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            line = line.split('\t')
            label = int(line[2])
            train_y.append(label)


    with open(config.FEATURES_test_FILE, 'rb') as f:
        test_features = pickle.load(f)

    with open(config.FEATURES_FILE, 'rb') as f:
        features = pickle.load(f)
        
    with open(config.OCR_FEATURES_test_FILE, 'rb') as f:
        ocr_test_features = pickle.load(f)
    with open(config.OCR_FEATURES_FILE, 'rb') as f:
        ocr_features = pickle.load(f)

    # TFIDF + SVD 降维后的特征
    with open('../data/train_x_250.pkl', 'rb') as f:
        train_x = pickle.load(f)
    with open('../data/test_x_250.pkl', 'rb') as f:
        test_x = pickle.load(f)

    # 联合OCR提取的特征
    with open('../data/ocr_train_x_250.pkl', 'rb') as f:
        train_ocr_x = pickle.load(f)

    with open('../data/ocr_test_x_250.pkl', 'rb') as f:
        test_ocr_x = pickle.load(f)
        
    scaler = MinMaxScaler()
    all_feature = np.concatenate([features, test_features, ocr_test_features, ocr_features], axis=0)
    scaler.fit(all_feature)
    features = scaler.transform(features)
    test_features = scaler.transform(test_features)
    ocr_features = scaler.transform(ocr_features)
    ocr_test_features = scaler.transform(ocr_test_features)
    
    train_x = np.concatenate((train_x, train_ocr_x, features, ocr_features), axis=-1)
    test_x = np.concatenate((test_x, test_ocr_x, test_features, ocr_test_features), axis=-1)
    train_y = np.array(train_y)
    return train_x, train_y, test_x

# %%
data_x, data_y, test = static_data_prepare()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# 这里先导入传统机器学习模型
model = config.model['model' + str(8)]()
model.train_predict(data_x[:10], data_y[:10], test[:10])
# Out:
# 0:	learn: -0.6834329	total: 61ms	remaining: 1m
# 1:	learn: -0.6788535	total: 63.2ms	remaining: 31.5s
# 2:	learn: -0.6703978	total: 65.4ms	remaining: 21.7s
# 3:	learn: -0.6586300	total: 67ms	remaining: 16.7s
# 4:	learn: -0.6488000	total: 68.7ms	remaining: 13.7s
# 5:	learn: -0.6398159	total: 70.5ms	remaining: 11.7s
# 6:	learn: -0.6320691	total: 72.9ms	remaining: 10.3s
# 7:	learn: -0.6261224	total: 76ms	remaining: 9.42s
# 8:	learn: -0.6213667	total: 79.7ms	remaining: 8.77s
# 9:	learn: -0.6119698	total: 82.6ms	remaining: 8.18s
# 10:	learn: -0.6028043	total: 84.8ms	remaining: 7.63s
# 11:	learn: -0.5972627	total: 86.9ms	remaining: 7.15s
# 12:	learn: -0.5913013	total: 88.9ms	remaining: 6.75s
# 13:	learn: -0.5864425	total: 91.8ms	remaining: 6.47s
# 14:	learn: -0.5821057	total: 95.7ms	remaining: 6.28s
# 15:	learn: -0.5763753	total: 98ms	remaining: 6.03s
# 16:	learn: -0.5679472	total: 100ms	remaining: 5.79s
# 17:	learn: -0.5632925	total: 102ms	remaining: 5.57s
# 18:	learn: -0.5587668	total: 106ms	remaining: 5.47s
# 19:	learn: -0.5538323	total: 109ms	remaining: 5.35s
# 20:	learn: -0.5484765	total: 111ms	remaining: 5.2s
# 21:	learn: -0.5440219	total: 114ms	remaining: 5.05s
# 22:	learn: -0.5379196	total: 117ms	remaining: 4.95s
# 23:	learn: -0.5319228	total: 119ms	remaining: 4.84s
# 24:	learn: -0.5279494	total: 121ms	remaining: 4.7s
# 25:	learn: -0.5220320	total: 123ms	remaining: 4.62s
# 26:	learn: -0.5184401	total: 126ms	remaining: 4.55s
# 27:	learn: -0.5139904	total: 129ms	remaining: 4.48s
# 28:	learn: -0.5068968	total: 131ms	remaining: 4.39s
# 29:	learn: -0.5004093	total: 133ms	remaining: 4.3s
# 30:	learn: -0.4966174	total: 136ms	remaining: 4.25s
# 31:	learn: -0.4899343	total: 138ms	remaining: 4.18s
# 32:	learn: -0.4866709	total: 140ms	remaining: 4.11s
# 33:	learn: -0.4822624	total: 143ms	remaining: 4.06s
# 34:	learn: -0.4766456	total: 145ms	remaining: 4.01s
# 35:	learn: -0.4731713	total: 148ms	remaining: 3.97s
# 36:	learn: -0.4656745	total: 150ms	remaining: 3.91s
# 37:	learn: -0.4596639	total: 153ms	remaining: 3.87s
# 38:	learn: -0.4567137	total: 156ms	remaining: 3.83s
# 39:	learn: -0.4530709	total: 158ms	remaining: 3.79s
# 40:	learn: -0.4498141	total: 161ms	remaining: 3.76s
# 41:	learn: -0.4459622	total: 165ms	remaining: 3.76s
# 42:	learn: -0.4391400	total: 167ms	remaining: 3.72s
# 43:	learn: -0.4364029	total: 170ms	remaining: 3.7s
# 44:	learn: -0.4317480	total: 172ms	remaining: 3.64s
# 45:	learn: -0.4281361	total: 175ms	remaining: 3.63s
# 46:	learn: -0.4235300	total: 177ms	remaining: 3.6s
# 47:	learn: -0.4205970	total: 181ms	remaining: 3.6s
# 48:	learn: -0.4170832	total: 184ms	remaining: 3.57s
# 49:	learn: -0.4113175	total: 186ms	remaining: 3.54s
# 50:	learn: -0.4085170	total: 190ms	remaining: 3.54s
# 51:	learn: -0.4028382	total: 192ms	remaining: 3.5s
# 52:	learn: -0.3989816	total: 195ms	remaining: 3.48s
# 53:	learn: -0.3925832	total: 196ms	remaining: 3.44s
# 54:	learn: -0.3873492	total: 198ms	remaining: 3.4s
# 55:	learn: -0.3835907	total: 201ms	remaining: 3.39s
# 56:	learn: -0.3806060	total: 204ms	remaining: 3.37s
# 57:	learn: -0.3759876	total: 205ms	remaining: 3.33s
# 58:	learn: -0.3707984	total: 207ms	remaining: 3.31s
# 59:	learn: -0.3684254	total: 211ms	remaining: 3.31s
# 60:	learn: -0.3634102	total: 213ms	remaining: 3.28s
# 61:	learn: -0.3593962	total: 215ms	remaining: 3.26s
# 62:	learn: -0.3554540	total: 217ms	remaining: 3.23s
# 63:	learn: -0.3533176	total: 220ms	remaining: 3.21s
# 64:	learn: -0.3480453	total: 222ms	remaining: 3.19s
# 65:	learn: -0.3444587	total: 224ms	remaining: 3.17s
# 66:	learn: -0.3415156	total: 226ms	remaining: 3.15s
# 67:	learn: -0.3394382	total: 229ms	remaining: 3.14s
# 68:	learn: -0.3370839	total: 232ms	remaining: 3.12s
# 69:	learn: -0.3321942	total: 233ms	remaining: 3.1s
# 70:	learn: -0.3288604	total: 236ms	remaining: 3.08s
# 71:	learn: -0.3269078	total: 239ms	remaining: 3.08s
# 72:	learn: -0.3249743	total: 243ms	remaining: 3.09s
# 73:	learn: -0.3203627	total: 245ms	remaining: 3.07s
# 74:	learn: -0.3158572	total: 247ms	remaining: 3.04s
# 75:	learn: -0.3114545	total: 249ms	remaining: 3.02s
# 76:	learn: -0.3083406	total: 251ms	remaining: 3.01s
# 77:	learn: -0.3041086	total: 253ms	remaining: 3s
# 78:	learn: -0.3026140	total: 257ms	remaining: 3s
# 79:	learn: -0.3009123	total: 262ms	remaining: 3.01s
# 80:	learn: -0.2973259	total: 264ms	remaining: 2.99s
# 81:	learn: -0.2944528	total: 266ms	remaining: 2.98s
# 82:	learn: -0.2921883	total: 269ms	remaining: 2.97s
# 83:	learn: -0.2894079	total: 272ms	remaining: 2.97s
# 84:	learn: -0.2855963	total: 275ms	remaining: 2.96s
# 85:	learn: -0.2818673	total: 277ms	remaining: 2.94s
# 86:	learn: -0.2792547	total: 279ms	remaining: 2.93s
# 87:	learn: -0.2777656	total: 283ms	remaining: 2.94s
# 88:	learn: -0.2762891	total: 287ms	remaining: 2.93s
# 89:	learn: -0.2752094	total: 289ms	remaining: 2.92s
# 90:	learn: -0.2736970	total: 292ms	remaining: 2.92s
# 91:	learn: -0.2712147	total: 296ms	remaining: 2.92s
# 92:	learn: -0.2687699	total: 298ms	remaining: 2.91s
# 93:	learn: -0.2658172	total: 300ms	remaining: 2.89s
# 94:	learn: -0.2634637	total: 302ms	remaining: 2.88s
# 95:	learn: -0.2615896	total: 305ms	remaining: 2.87s
# 96:	learn: -0.2599729	total: 307ms	remaining: 2.86s
# 97:	learn: -0.2586112	total: 309ms	remaining: 2.84s
# 98:	learn: -0.2554471	total: 311ms	remaining: 2.83s
# 99:	learn: -0.2532481	total: 313ms	remaining: 2.82s
# 100:	learn: -0.2501937	total: 315ms	remaining: 2.8s
# 101:	learn: -0.2475815	total: 318ms	remaining: 2.79s
# 102:	learn: -0.2446423	total: 319ms	remaining: 2.78s
# 103:	learn: -0.2424874	total: 321ms	remaining: 2.77s
# 104:	learn: -0.2413141	total: 325ms	remaining: 2.77s
# 105:	learn: -0.2395388	total: 328ms	remaining: 2.77s
# 106:	learn: -0.2384712	total: 330ms	remaining: 2.75s
# 107:	learn: -0.2357101	total: 332ms	remaining: 2.74s
# 108:	learn: -0.2330029	total: 333ms	remaining: 2.72s
# 109:	learn: -0.2319905	total: 335ms	remaining: 2.71s
# 110:	learn: -0.2309911	total: 337ms	remaining: 2.7s
# 111:	learn: -0.2283751	total: 339ms	remaining: 2.69s
# 112:	learn: -0.2261417	total: 341ms	remaining: 2.68s
# 113:	learn: -0.2243586	total: 343ms	remaining: 2.67s
# 114:	learn: -0.2221968	total: 345ms	remaining: 2.66s
# 115:	learn: -0.2209728	total: 347ms	remaining: 2.65s
# 116:	learn: -0.2196514	total: 349ms	remaining: 2.64s
# 117:	learn: -0.2187944	total: 352ms	remaining: 2.63s
# 118:	learn: -0.2171115	total: 354ms	remaining: 2.62s
# 119:	learn: -0.2161414	total: 358ms	remaining: 2.63s
# 120:	learn: -0.2149739	total: 361ms	remaining: 2.62s
# 121:	learn: -0.2129660	total: 363ms	remaining: 2.62s
# 122:	learn: -0.2106901	total: 365ms	remaining: 2.6s
# 123:	learn: -0.2091171	total: 367ms	remaining: 2.6s
# 124:	learn: -0.2069115	total: 369ms	remaining: 2.58s
# 125:	learn: -0.2059749	total: 371ms	remaining: 2.57s
# 126:	learn: -0.2050898	total: 375ms	remaining: 2.58s
# 127:	learn: -0.2035901	total: 378ms	remaining: 2.58s
# 128:	learn: -0.2027992	total: 381ms	remaining: 2.57s
# 129:	learn: -0.2007060	total: 383ms	remaining: 2.56s
# 130:	learn: -0.1997416	total: 385ms	remaining: 2.55s
# 131:	learn: -0.1990333	total: 390ms	remaining: 2.56s
# 132:	learn: -0.1981992	total: 394ms	remaining: 2.57s
# 133:	learn: -0.1974533	total: 397ms	remaining: 2.56s
# 134:	learn: -0.1954532	total: 399ms	remaining: 2.56s
# 135:	learn: -0.1937533	total: 402ms	remaining: 2.55s
# 136:	learn: -0.1918182	total: 404ms	remaining: 2.54s
# 137:	learn: -0.1899165	total: 406ms	remaining: 2.53s
# 138:	learn: -0.1890186	total: 409ms	remaining: 2.53s
# 139:	learn: -0.1871648	total: 411ms	remaining: 2.52s
# 140:	learn: -0.1864610	total: 414ms	remaining: 2.52s
# 141:	learn: -0.1855597	total: 418ms	remaining: 2.52s
# 142:	learn: -0.1846979	total: 422ms	remaining: 2.53s
# 143:	learn: -0.1831614	total: 425ms	remaining: 2.52s
# 144:	learn: -0.1814067	total: 426ms	remaining: 2.51s
# 145:	learn: -0.1799201	total: 429ms	remaining: 2.51s
# 146:	learn: -0.1782197	total: 431ms	remaining: 2.5s
# 147:	learn: -0.1767808	total: 433ms	remaining: 2.49s
# 148:	learn: -0.1759637	total: 436ms	remaining: 2.49s
# 149:	learn: -0.1752020	total: 438ms	remaining: 2.48s
# 150:	learn: -0.1745352	total: 443ms	remaining: 2.49s
# 151:	learn: -0.1731489	total: 446ms	remaining: 2.49s
# 152:	learn: -0.1720403	total: 449ms	remaining: 2.48s
# 153:	learn: -0.1706911	total: 452ms	remaining: 2.48s
# 154:	learn: -0.1693622	total: 454ms	remaining: 2.48s
# 155:	learn: -0.1682991	total: 458ms	remaining: 2.48s
# 156:	learn: -0.1678653	total: 462ms	remaining: 2.48s
# 157:	learn: -0.1671706	total: 464ms	remaining: 2.47s
# 158:	learn: -0.1661331	total: 467ms	remaining: 2.47s
# 159:	learn: -0.1646543	total: 470ms	remaining: 2.46s
# 160:	learn: -0.1639587	total: 473ms	remaining: 2.47s
# 161:	learn: -0.1627229	total: 477ms	remaining: 2.47s
# 162:	learn: -0.1621369	total: 481ms	remaining: 2.47s
# 163:	learn: -0.1607204	total: 484ms	remaining: 2.47s
# 164:	learn: -0.1601474	total: 488ms	remaining: 2.47s
# 165:	learn: -0.1595781	total: 494ms	remaining: 2.48s
# 166:	learn: -0.1582008	total: 496ms	remaining: 2.47s
# 167:	learn: -0.1568444	total: 498ms	remaining: 2.47s
# 168:	learn: -0.1557033	total: 500ms	remaining: 2.46s
# 169:	learn: -0.1550495	total: 504ms	remaining: 2.46s
# 170:	learn: -0.1544037	total: 507ms	remaining: 2.46s
# 171:	learn: -0.1531049	total: 509ms	remaining: 2.45s
# 172:	learn: -0.1526406	total: 512ms	remaining: 2.45s
# 173:	learn: -0.1515550	total: 515ms	remaining: 2.44s
# 174:	learn: -0.1505000	total: 517ms	remaining: 2.44s
# 175:	learn: -0.1496420	total: 519ms	remaining: 2.43s
# 176:	learn: -0.1485954	total: 522ms	remaining: 2.43s
# 177:	learn: -0.1473821	total: 524ms	remaining: 2.42s
# 178:	learn: -0.1467903	total: 527ms	remaining: 2.42s
# 179:	learn: -0.1456032	total: 529ms	remaining: 2.41s
# 180:	learn: -0.1446081	total: 531ms	remaining: 2.4s
# 181:	learn: -0.1438632	total: 534ms	remaining: 2.4s
# 182:	learn: -0.1428894	total: 536ms	remaining: 2.39s
# 183:	learn: -0.1417584	total: 538ms	remaining: 2.38s
# 184:	learn: -0.1406432	total: 540ms	remaining: 2.38s
# 185:	learn: -0.1396854	total: 541ms	remaining: 2.37s
# 186:	learn: -0.1391499	total: 544ms	remaining: 2.37s
# 187:	learn: -0.1380713	total: 546ms	remaining: 2.36s
# 188:	learn: -0.1370077	total: 548ms	remaining: 2.35s
# 189:	learn: -0.1365077	total: 551ms	remaining: 2.35s
# 190:	learn: -0.1356311	total: 552ms	remaining: 2.34s
# 191:	learn: -0.1352094	total: 555ms	remaining: 2.34s
# 192:	learn: -0.1343390	total: 557ms	remaining: 2.33s
# 193:	learn: -0.1334796	total: 559ms	remaining: 2.32s
# 194:	learn: -0.1324787	total: 561ms	remaining: 2.31s
# 195:	learn: -0.1314912	total: 563ms	remaining: 2.31s
# 196:	learn: -0.1306654	total: 565ms	remaining: 2.3s
# 197:	learn: -0.1297022	total: 566ms	remaining: 2.29s
# 198:	learn: -0.1288975	total: 568ms	remaining: 2.29s
# 199:	learn: -0.1285127	total: 571ms	remaining: 2.29s
# 200:	learn: -0.1275780	total: 573ms	remaining: 2.28s
# 201:	learn: -0.1266556	total: 575ms	remaining: 2.27s
# 202:	learn: -0.1258855	total: 577ms	remaining: 2.26s
# 203:	learn: -0.1255169	total: 579ms	remaining: 2.26s
# 204:	learn: -0.1251504	total: 584ms	remaining: 2.26s
# 205:	learn: -0.1242594	total: 586ms	remaining: 2.26s
# 206:	learn: -0.1233799	total: 587ms	remaining: 2.25s
# 207:	learn: -0.1230249	total: 590ms	remaining: 2.25s
# 208:	learn: -0.1221611	total: 592ms	remaining: 2.24s
# 209:	learn: -0.1214402	total: 594ms	remaining: 2.23s
# 210:	learn: -0.1205966	total: 596ms	remaining: 2.23s
# 211:	learn: -0.1197635	total: 598ms	remaining: 2.22s
# 212:	learn: -0.1190690	total: 601ms	remaining: 2.22s
# 213:	learn: -0.1185097	total: 603ms	remaining: 2.21s
# 214:	learn: -0.1177027	total: 605ms	remaining: 2.21s
# 215:	learn: -0.1170306	total: 607ms	remaining: 2.2s
# 216:	learn: -0.1162419	total: 608ms	remaining: 2.19s
# 217:	learn: -0.1155856	total: 610ms	remaining: 2.19s
# 218:	learn: -0.1148145	total: 612ms	remaining: 2.18s
# 219:	learn: -0.1140528	total: 614ms	remaining: 2.18s
# 220:	learn: -0.1136339	total: 617ms	remaining: 2.17s
# 221:	learn: -0.1130029	total: 619ms	remaining: 2.17s
# 222:	learn: -0.1123801	total: 621ms	remaining: 2.16s
# 223:	learn: -0.1118565	total: 623ms	remaining: 2.16s
# 224:	learn: -0.1112454	total: 624ms	remaining: 2.15s
# 225:	learn: -0.1106408	total: 626ms	remaining: 2.14s
# 226:	learn: -0.1099288	total: 628ms	remaining: 2.14s
# 227:	learn: -0.1092252	total: 630ms	remaining: 2.13s
# 228:	learn: -0.1085297	total: 632ms	remaining: 2.13s
# 229:	learn: -0.1078424	total: 634ms	remaining: 2.12s
# 230:	learn: -0.1071629	total: 636ms	remaining: 2.12s
# 231:	learn: -0.1065991	total: 638ms	remaining: 2.11s
# 232:	learn: -0.1063273	total: 643ms	remaining: 2.12s
# 233:	learn: -0.1060569	total: 646ms	remaining: 2.12s
# 234:	learn: -0.1053979	total: 648ms	remaining: 2.11s
# 235:	learn: -0.1047464	total: 651ms	remaining: 2.11s
# 236:	learn: -0.1043895	total: 654ms	remaining: 2.1s
# 237:	learn: -0.1037494	total: 656ms	remaining: 2.1s
# 238:	learn: -0.1031165	total: 658ms	remaining: 2.1s
# 239:	learn: -0.1028611	total: 662ms	remaining: 2.1s
# 240:	learn: -0.1026070	total: 665ms	remaining: 2.09s
# 241:	learn: -0.1020865	total: 667ms	remaining: 2.09s
# 242:	learn: -0.1018358	total: 671ms	remaining: 2.09s
# 243:	learn: -0.1015389	total: 673ms	remaining: 2.08s
# 244:	learn: -0.1009305	total: 674ms	remaining: 2.08s
# 245:	learn: -0.1005976	total: 677ms	remaining: 2.07s
# 246:	learn: -0.1000897	total: 679ms	remaining: 2.07s
# 247:	learn: -0.0998482	total: 681ms	remaining: 2.07s
# 248:	learn: -0.0995219	total: 684ms	remaining: 2.06s
# 249:	learn: -0.0990300	total: 685ms	remaining: 2.06s
# 250:	learn: -0.0985388	total: 687ms	remaining: 2.05s
# 251:	learn: -0.0980561	total: 689ms	remaining: 2.04s
# 252:	learn: -0.0978235	total: 693ms	remaining: 2.04s
# 253:	learn: -0.0973474	total: 695ms	remaining: 2.04s
# 254:	learn: -0.0968760	total: 697ms	remaining: 2.04s
# 255:	learn: -0.0963180	total: 699ms	remaining: 2.03s
# 256:	learn: -0.0960930	total: 702ms	remaining: 2.03s
# 257:	learn: -0.0956330	total: 704ms	remaining: 2.02s
# 258:	learn: -0.0954109	total: 710ms	remaining: 2.03s
# 259:	learn: -0.0948684	total: 711ms	remaining: 2.02s
# 260:	learn: -0.0946083	total: 713ms	remaining: 2.02s
# 261:	learn: -0.0942261	total: 715ms	remaining: 2.01s
# 262:	learn: -0.0936960	total: 717ms	remaining: 2.01s
# 263:	learn: -0.0932570	total: 719ms	remaining: 2s
# 264:	learn: -0.0929021	total: 721ms	remaining: 2s
# 265:	learn: -0.0923857	total: 723ms	remaining: 1.99s
# 266:	learn: -0.0921775	total: 726ms	remaining: 1.99s
# 267:	learn: -0.0916685	total: 728ms	remaining: 1.99s
# 268:	learn: -0.0911647	total: 730ms	remaining: 1.98s
# 269:	learn: -0.0906660	total: 731ms	remaining: 1.98s
# 270:	learn: -0.0903294	total: 734ms	remaining: 1.97s
# 271:	learn: -0.0898391	total: 735ms	remaining: 1.97s
# 272:	learn: -0.0894336	total: 738ms	remaining: 1.96s
# 273:	learn: -0.0890317	total: 740ms	remaining: 1.96s
# 274:	learn: -0.0885544	total: 741ms	remaining: 1.95s
# 275:	learn: -0.0880818	total: 743ms	remaining: 1.95s
# 276:	learn: -0.0877613	total: 745ms	remaining: 1.95s
# 277:	learn: -0.0874277	total: 747ms	remaining: 1.94s
# 278:	learn: -0.0871735	total: 749ms	remaining: 1.94s
# 279:	learn: -0.0867145	total: 751ms	remaining: 1.93s
# 280:	learn: -0.0863352	total: 753ms	remaining: 1.93s
# 281:	learn: -0.0860286	total: 755ms	remaining: 1.92s
# 282:	learn: -0.0858173	total: 758ms	remaining: 1.92s
# 283:	learn: -0.0853714	total: 760ms	remaining: 1.92s
# 284:	learn: -0.0850033	total: 762ms	remaining: 1.91s
# 285:	learn: -0.0845653	total: 764ms	remaining: 1.91s
# 286:	learn: -0.0842040	total: 766ms	remaining: 1.9s
# 287:	learn: -0.0837736	total: 768ms	remaining: 1.9s
# 288:	learn: -0.0833473	total: 769ms	remaining: 1.89s
# 289:	learn: -0.0829251	total: 771ms	remaining: 1.89s
# 290:	learn: -0.0825769	total: 773ms	remaining: 1.88s
# 291:	learn: -0.0821619	total: 775ms	remaining: 1.88s
# 292:	learn: -0.0817507	total: 777ms	remaining: 1.87s
# 293:	learn: -0.0815850	total: 780ms	remaining: 1.87s
# 294:	learn: -0.0813095	total: 783ms	remaining: 1.87s
# 295:	learn: -0.0809063	total: 784ms	remaining: 1.86s
# 296:	learn: -0.0805068	total: 786ms	remaining: 1.86s
# 297:	learn: -0.0801109	total: 788ms	remaining: 1.86s
# 298:	learn: -0.0797788	total: 790ms	remaining: 1.85s
# 299:	learn: -0.0793896	total: 792ms	remaining: 1.85s
# 300:	learn: -0.0790632	total: 794ms	remaining: 1.84s
# 301:	learn: -0.0789077	total: 798ms	remaining: 1.84s
# 302:	learn: -0.0785264	total: 800ms	remaining: 1.84s
# 303:	learn: -0.0783432	total: 803ms	remaining: 1.84s
# 304:	learn: -0.0781366	total: 806ms	remaining: 1.84s
# 305:	learn: -0.0778827	total: 808ms	remaining: 1.83s
# 306:	learn: -0.0775106	total: 810ms	remaining: 1.83s
# 307:	learn: -0.0773319	total: 814ms	remaining: 1.83s
# 308:	learn: -0.0771828	total: 817ms	remaining: 1.83s
# 309:	learn: -0.0768783	total: 819ms	remaining: 1.82s
# 310:	learn: -0.0766791	total: 823ms	remaining: 1.82s
# 311:	learn: -0.0764341	total: 825ms	remaining: 1.82s
# 312:	learn: -0.0762882	total: 829ms	remaining: 1.82s
# 313:	learn: -0.0760919	total: 832ms	remaining: 1.82s
# 314:	learn: -0.0757957	total: 834ms	remaining: 1.81s
# 315:	learn: -0.0754420	total: 836ms	remaining: 1.81s
# 316:	learn: -0.0750914	total: 838ms	remaining: 1.81s
# 317:	learn: -0.0748027	total: 840ms	remaining: 1.8s
# 318:	learn: -0.0746404	total: 844ms	remaining: 1.8s
# 319:	learn: -0.0744522	total: 847ms	remaining: 1.8s
# 320:	learn: -0.0741101	total: 849ms	remaining: 1.79s
# 321:	learn: -0.0738886	total: 851ms	remaining: 1.79s
# 322:	learn: -0.0737517	total: 855ms	remaining: 1.79s
# 323:	learn: -0.0735677	total: 857ms	remaining: 1.79s
# 324:	learn: -0.0732333	total: 859ms	remaining: 1.78s
# 325:	learn: -0.0729017	total: 861ms	remaining: 1.78s
# 326:	learn: -0.0727683	total: 864ms	remaining: 1.78s
# 327:	learn: -0.0724407	total: 865ms	remaining: 1.77s
# 328:	learn: -0.0722629	total: 868ms	remaining: 1.77s
# 329:	learn: -0.0719942	total: 871ms	remaining: 1.77s
# 330:	learn: -0.0717142	total: 873ms	remaining: 1.76s
# 331:	learn: -0.0715850	total: 877ms	remaining: 1.76s
# 332:	learn: -0.0714561	total: 881ms	remaining: 1.76s
# 333:	learn: -0.0711395	total: 883ms	remaining: 1.76s
# 334:	learn: -0.0709671	total: 886ms	remaining: 1.76s
# 335:	learn: -0.0708404	total: 889ms	remaining: 1.76s
# 336:	learn: -0.0705815	total: 892ms	remaining: 1.75s
# 337:	learn: -0.0704362	total: 895ms	remaining: 1.75s
# 338:	learn: -0.0702677	total: 897ms	remaining: 1.75s
# 339:	learn: -0.0701434	total: 900ms	remaining: 1.75s
# 340:	learn: -0.0698894	total: 902ms	remaining: 1.74s
# 341:	learn: -0.0696372	total: 904ms	remaining: 1.74s
# 342:	learn: -0.0694956	total: 907ms	remaining: 1.74s
# 343:	learn: -0.0693738	total: 910ms	remaining: 1.73s
# 344:	learn: -0.0691252	total: 912ms	remaining: 1.73s
# 345:	learn: -0.0689627	total: 914ms	remaining: 1.73s
# 346:	learn: -0.0686665	total: 916ms	remaining: 1.72s
# 347:	learn: -0.0685286	total: 919ms	remaining: 1.72s
# 348:	learn: -0.0683875	total: 922ms	remaining: 1.72s
# 349:	learn: -0.0681334	total: 924ms	remaining: 1.72s
# 350:	learn: -0.0679976	total: 927ms	remaining: 1.71s
# 351:	learn: -0.0678401	total: 930ms	remaining: 1.71s
# 352:	learn: -0.0677018	total: 934ms	remaining: 1.71s
# 353:	learn: -0.0675458	total: 937ms	remaining: 1.71s
# 354:	learn: -0.0672610	total: 938ms	remaining: 1.7s
# 355:	learn: -0.0670266	total: 941ms	remaining: 1.7s
# 356:	learn: -0.0669128	total: 944ms	remaining: 1.7s
# 357:	learn: -0.0667995	total: 947ms	remaining: 1.7s
# 358:	learn: -0.0665206	total: 948ms	remaining: 1.69s
# 359:	learn: -0.0662439	total: 950ms	remaining: 1.69s
# 360:	learn: -0.0661328	total: 954ms	remaining: 1.69s
# 361:	learn: -0.0658591	total: 956ms	remaining: 1.68s
# 362:	learn: -0.0655876	total: 957ms	remaining: 1.68s
# 363:	learn: -0.0653181	total: 959ms	remaining: 1.68s
# 364:	learn: -0.0650964	total: 962ms	remaining: 1.67s
# 365:	learn: -0.0649164	total: 964ms	remaining: 1.67s
# 366:	learn: -0.0646522	total: 966ms	remaining: 1.67s
# 367:	learn: -0.0644348	total: 968ms	remaining: 1.66s
# 368:	learn: -0.0642137	total: 970ms	remaining: 1.66s
# 369:	learn: -0.0639549	total: 972ms	remaining: 1.65s
# 370:	learn: -0.0637420	total: 973ms	remaining: 1.65s
# 371:	learn: -0.0634867	total: 975ms	remaining: 1.65s
# 372:	learn: -0.0632768	total: 977ms	remaining: 1.64s
# 373:	learn: -0.0630683	total: 979ms	remaining: 1.64s
# 374:	learn: -0.0629670	total: 981ms	remaining: 1.64s
# 375:	learn: -0.0628660	total: 984ms	remaining: 1.63s
# 376:	learn: -0.0626173	total: 986ms	remaining: 1.63s
# 377:	learn: -0.0625173	total: 990ms	remaining: 1.63s
# 378:	learn: -0.0623509	total: 992ms	remaining: 1.63s
# 379:	learn: -0.0621482	total: 995ms	remaining: 1.62s
# 380:	learn: -0.0619048	total: 996ms	remaining: 1.62s
# 381:	learn: -0.0617887	total: 999ms	remaining: 1.62s
# 382:	learn: -0.0615896	total: 1s	remaining: 1.61s
# 383:	learn: -0.0613917	total: 1s	remaining: 1.61s
# 384:	learn: -0.0612775	total: 1.01s	remaining: 1.61s
# 385:	learn: -0.0611174	total: 1.01s	remaining: 1.6s
# 386:	learn: -0.0609581	total: 1.01s	remaining: 1.6s
# 387:	learn: -0.0607235	total: 1.01s	remaining: 1.6s
# 388:	learn: -0.0604906	total: 1.02s	remaining: 1.6s
# 389:	learn: -0.0602593	total: 1.02s	remaining: 1.6s
# 390:	learn: -0.0601345	total: 1.02s	remaining: 1.6s
# 391:	learn: -0.0600101	total: 1.03s	remaining: 1.59s
# 392:	learn: -0.0598220	total: 1.03s	remaining: 1.59s
# 393:	learn: -0.0595955	total: 1.03s	remaining: 1.59s
# 394:	learn: -0.0594903	total: 1.04s	remaining: 1.59s
# 395:	learn: -0.0593995	total: 1.04s	remaining: 1.59s
# 396:	learn: -0.0592923	total: 1.05s	remaining: 1.59s
# 397:	learn: -0.0591713	total: 1.05s	remaining: 1.59s
# 398:	learn: -0.0590262	total: 1.05s	remaining: 1.59s
# 399:	learn: -0.0588055	total: 1.06s	remaining: 1.59s
# 400:	learn: -0.0586194	total: 1.06s	remaining: 1.58s
# 401:	learn: -0.0584394	total: 1.06s	remaining: 1.58s
# 402:	learn: -0.0583517	total: 1.07s	remaining: 1.58s
# 403:	learn: -0.0582643	total: 1.07s	remaining: 1.58s
# 404:	learn: -0.0581772	total: 1.07s	remaining: 1.58s
# 405:	learn: -0.0579625	total: 1.08s	remaining: 1.57s
# 406:	learn: -0.0577863	total: 1.08s	remaining: 1.57s
# 407:	learn: -0.0575742	total: 1.08s	remaining: 1.57s
# 408:	learn: -0.0574003	total: 1.08s	remaining: 1.56s
# 409:	learn: -0.0572274	total: 1.08s	remaining: 1.56s
# 410:	learn: -0.0570870	total: 1.09s	remaining: 1.56s
# 411:	learn: -0.0569473	total: 1.09s	remaining: 1.56s
# 412:	learn: -0.0568353	total: 1.09s	remaining: 1.55s
# 413:	learn: -0.0566299	total: 1.1s	remaining: 1.55s
# 414:	learn: -0.0564987	total: 1.1s	remaining: 1.55s
# 415:	learn: -0.0563251	total: 1.1s	remaining: 1.55s
# 416:	learn: -0.0562307	total: 1.1s	remaining: 1.54s
# 417:	learn: -0.0561142	total: 1.11s	remaining: 1.54s
# 418:	learn: -0.0560183	total: 1.11s	remaining: 1.54s
# 419:	learn: -0.0558835	total: 1.11s	remaining: 1.54s
# 420:	learn: -0.0557755	total: 1.12s	remaining: 1.54s
# 421:	learn: -0.0556679	total: 1.12s	remaining: 1.54s
# 422:	learn: -0.0555048	total: 1.13s	remaining: 1.54s
# 423:	learn: -0.0553084	total: 1.13s	remaining: 1.53s
# 424:	learn: -0.0551133	total: 1.13s	remaining: 1.53s
# 425:	learn: -0.0549195	total: 1.13s	remaining: 1.53s
# 426:	learn: -0.0547270	total: 1.14s	remaining: 1.53s
# 427:	learn: -0.0545358	total: 1.14s	remaining: 1.52s
# 428:	learn: -0.0543459	total: 1.14s	remaining: 1.52s
# 429:	learn: -0.0541573	total: 1.14s	remaining: 1.52s
# 430:	learn: -0.0539698	total: 1.15s	remaining: 1.51s
# 431:	learn: -0.0538161	total: 1.15s	remaining: 1.51s
# 432:	learn: -0.0536309	total: 1.15s	remaining: 1.51s
# 433:	learn: -0.0534791	total: 1.15s	remaining: 1.5s
# 434:	learn: -0.0533282	total: 1.16s	remaining: 1.5s
# 435:	learn: -0.0531462	total: 1.16s	remaining: 1.5s
# 436:	learn: -0.0530731	total: 1.16s	remaining: 1.5s
# 437:	learn: -0.0528927	total: 1.17s	remaining: 1.5s
# 438:	learn: -0.0528204	total: 1.17s	remaining: 1.5s
# 439:	learn: -0.0527482	total: 1.17s	remaining: 1.49s
# 440:	learn: -0.0525699	total: 1.18s	remaining: 1.49s
# 441:	learn: -0.0524506	total: 1.18s	remaining: 1.49s
# 442:	learn: -0.0523550	total: 1.18s	remaining: 1.49s
# 443:	learn: -0.0522290	total: 1.19s	remaining: 1.49s
# 444:	learn: -0.0521453	total: 1.19s	remaining: 1.48s
# 445:	learn: -0.0520014	total: 1.19s	remaining: 1.48s
# 446:	learn: -0.0518503	total: 1.19s	remaining: 1.48s
# 447:	learn: -0.0517677	total: 1.2s	remaining: 1.48s
# 448:	learn: -0.0516259	total: 1.2s	remaining: 1.47s
# 449:	learn: -0.0514548	total: 1.2s	remaining: 1.47s
# 450:	learn: -0.0513146	total: 1.21s	remaining: 1.47s
# 451:	learn: -0.0511455	total: 1.21s	remaining: 1.47s
# 452:	learn: -0.0510070	total: 1.21s	remaining: 1.46s
# 453:	learn: -0.0508649	total: 1.22s	remaining: 1.46s
# 454:	learn: -0.0507279	total: 1.22s	remaining: 1.46s
# 455:	learn: -0.0506506	total: 1.23s	remaining: 1.46s
# 456:	learn: -0.0505840	total: 1.23s	remaining: 1.46s
# 457:	learn: -0.0505176	total: 1.24s	remaining: 1.46s
# 458:	learn: -0.0503745	total: 1.24s	remaining: 1.46s
# 459:	learn: -0.0502113	total: 1.24s	remaining: 1.46s
# 460:	learn: -0.0500776	total: 1.25s	remaining: 1.46s
# 461:	learn: -0.0499738	total: 1.25s	remaining: 1.45s
# 462:	learn: -0.0498130	total: 1.25s	remaining: 1.45s
# 463:	learn: -0.0496533	total: 1.25s	remaining: 1.45s
# 464:	learn: -0.0494945	total: 1.25s	remaining: 1.44s
# 465:	learn: -0.0493644	total: 1.26s	remaining: 1.44s
# 466:	learn: -0.0492073	total: 1.26s	remaining: 1.44s
# 467:	learn: -0.0490512	total: 1.26s	remaining: 1.44s
# 468:	learn: -0.0489789	total: 1.27s	remaining: 1.43s
# 469:	learn: -0.0488514	total: 1.27s	remaining: 1.43s
# 470:	learn: -0.0486974	total: 1.27s	remaining: 1.43s
# 471:	learn: -0.0485944	total: 1.27s	remaining: 1.43s
# 472:	learn: -0.0484689	total: 1.28s	remaining: 1.42s
# 473:	learn: -0.0483964	total: 1.28s	remaining: 1.42s
# 474:	learn: -0.0482452	total: 1.28s	remaining: 1.42s
# 475:	learn: -0.0481580	total: 1.28s	remaining: 1.42s
# 476:	learn: -0.0480770	total: 1.29s	remaining: 1.41s
# 477:	learn: -0.0480168	total: 1.29s	remaining: 1.41s
# 478:	learn: -0.0479473	total: 1.29s	remaining: 1.41s
# 479:	learn: -0.0477988	total: 1.3s	remaining: 1.41s
# 480:	learn: -0.0476734	total: 1.3s	remaining: 1.4s
# 481:	learn: -0.0475265	total: 1.3s	remaining: 1.4s
# 482:	learn: -0.0473804	total: 1.3s	remaining: 1.4s
# 483:	learn: -0.0472608	total: 1.31s	remaining: 1.39s
# 484:	learn: -0.0471827	total: 1.31s	remaining: 1.39s
# 485:	learn: -0.0471049	total: 1.31s	remaining: 1.39s
# 486:	learn: -0.0469613	total: 1.31s	remaining: 1.38s
# 487:	learn: -0.0468186	total: 1.32s	remaining: 1.38s
# 488:	learn: -0.0466767	total: 1.32s	remaining: 1.38s
# 489:	learn: -0.0465356	total: 1.32s	remaining: 1.37s
# 490:	learn: -0.0464200	total: 1.32s	remaining: 1.37s
# 491:	learn: -0.0463534	total: 1.32s	remaining: 1.37s
# 492:	learn: -0.0462782	total: 1.33s	remaining: 1.36s
# 493:	learn: -0.0461395	total: 1.33s	remaining: 1.36s
# 494:	learn: -0.0460015	total: 1.33s	remaining: 1.36s
# 495:	learn: -0.0459360	total: 1.33s	remaining: 1.35s
# 496:	learn: -0.0458622	total: 1.33s	remaining: 1.35s
# 497:	learn: -0.0457499	total: 1.34s	remaining: 1.35s
# 498:	learn: -0.0456851	total: 1.34s	remaining: 1.34s
# 499:	learn: -0.0455498	total: 1.34s	remaining: 1.34s
# 500:	learn: -0.0454389	total: 1.34s	remaining: 1.34s
# 501:	learn: -0.0453242	total: 1.35s	remaining: 1.33s
# 502:	learn: -0.0452144	total: 1.35s	remaining: 1.33s
# 503:	learn: -0.0451052	total: 1.35s	remaining: 1.33s
# 504:	learn: -0.0449731	total: 1.35s	remaining: 1.32s
# 505:	learn: -0.0449022	total: 1.35s	remaining: 1.32s
# 506:	learn: -0.0448165	total: 1.36s	remaining: 1.32s
# 507:	learn: -0.0447313	total: 1.36s	remaining: 1.32s
# 508:	learn: -0.0446707	total: 1.36s	remaining: 1.31s
# 509:	learn: -0.0445410	total: 1.36s	remaining: 1.31s
# 510:	learn: -0.0444810	total: 1.36s	remaining: 1.3s
# 511:	learn: -0.0444211	total: 1.37s	remaining: 1.3s
# 512:	learn: -0.0443120	total: 1.37s	remaining: 1.3s
# 513:	learn: -0.0442260	total: 1.37s	remaining: 1.3s
# 514:	learn: -0.0440988	total: 1.37s	remaining: 1.29s
# 515:	learn: -0.0440306	total: 1.37s	remaining: 1.29s
# 516:	learn: -0.0439798	total: 1.38s	remaining: 1.29s
# 517:	learn: -0.0438762	total: 1.38s	remaining: 1.28s
# 518:	learn: -0.0437730	total: 1.38s	remaining: 1.28s
# 519:	learn: -0.0437136	total: 1.38s	remaining: 1.27s
# 520:	learn: -0.0436112	total: 1.38s	remaining: 1.27s
# 521:	learn: -0.0434874	total: 1.38s	remaining: 1.27s
# 522:	learn: -0.0433985	total: 1.38s	remaining: 1.26s
# 523:	learn: -0.0432975	total: 1.39s	remaining: 1.26s
# 524:	learn: -0.0431970	total: 1.39s	remaining: 1.25s
# 525:	learn: -0.0430936	total: 1.39s	remaining: 1.25s
# 526:	learn: -0.0429726	total: 1.39s	remaining: 1.25s
# 527:	learn: -0.0428522	total: 1.39s	remaining: 1.24s
# 528:	learn: -0.0427325	total: 1.39s	remaining: 1.24s
# 529:	learn: -0.0426345	total: 1.4s	remaining: 1.24s
# 530:	learn: -0.0425160	total: 1.4s	remaining: 1.23s
# 531:	learn: -0.0424611	total: 1.4s	remaining: 1.23s
# 532:	learn: -0.0424063	total: 1.4s	remaining: 1.23s
# 533:	learn: -0.0423296	total: 1.41s	remaining: 1.23s
# 534:	learn: -0.0422459	total: 1.41s	remaining: 1.23s
# 535:	learn: -0.0421295	total: 1.41s	remaining: 1.22s
# 536:	learn: -0.0420828	total: 1.41s	remaining: 1.22s
# 537:	learn: -0.0419672	total: 1.41s	remaining: 1.21s
# 538:	learn: -0.0419053	total: 1.42s	remaining: 1.21s
# 539:	learn: -0.0418108	total: 1.42s	remaining: 1.21s
# 540:	learn: -0.0417323	total: 1.42s	remaining: 1.2s
# 541:	learn: -0.0416550	total: 1.42s	remaining: 1.2s
# 542:	learn: -0.0415940	total: 1.42s	remaining: 1.2s
# 543:	learn: -0.0415484	total: 1.43s	remaining: 1.2s
# 544:	learn: -0.0414556	total: 1.43s	remaining: 1.19s
# 545:	learn: -0.0413433	total: 1.43s	remaining: 1.19s
# 546:	learn: -0.0412315	total: 1.43s	remaining: 1.18s
# 547:	learn: -0.0411204	total: 1.43s	remaining: 1.18s
# 548:	learn: -0.0410098	total: 1.43s	remaining: 1.18s
# 549:	learn: -0.0409193	total: 1.43s	remaining: 1.17s
# 550:	learn: -0.0408292	total: 1.43s	remaining: 1.17s
# 551:	learn: -0.0407579	total: 1.44s	remaining: 1.17s
# 552:	learn: -0.0406492	total: 1.44s	remaining: 1.16s
# 553:	learn: -0.0405410	total: 1.44s	remaining: 1.16s
# 554:	learn: -0.0404526	total: 1.44s	remaining: 1.15s
# 555:	learn: -0.0403454	total: 1.44s	remaining: 1.15s
# 556:	learn: -0.0402388	total: 1.44s	remaining: 1.15s
# 557:	learn: -0.0401516	total: 1.44s	remaining: 1.14s
# 558:	learn: -0.0400903	total: 1.45s	remaining: 1.14s
# 559:	learn: -0.0400215	total: 1.45s	remaining: 1.14s
# 560:	learn: -0.0399165	total: 1.45s	remaining: 1.13s
# 561:	learn: -0.0398745	total: 1.45s	remaining: 1.13s
# 562:	learn: -0.0397859	total: 1.45s	remaining: 1.13s
# 563:	learn: -0.0397258	total: 1.46s	remaining: 1.12s
# 564:	learn: -0.0396766	total: 1.46s	remaining: 1.12s
# 565:	learn: -0.0396351	total: 1.46s	remaining: 1.12s
# 566:	learn: -0.0395862	total: 1.46s	remaining: 1.12s
# 567:	learn: -0.0395449	total: 1.47s	remaining: 1.11s
# 568:	learn: -0.0394752	total: 1.47s	remaining: 1.11s
# 569:	learn: -0.0393910	total: 1.47s	remaining: 1.11s
# 570:	learn: -0.0393247	total: 1.47s	remaining: 1.1s
# 571:	learn: -0.0392232	total: 1.47s	remaining: 1.1s
# 572:	learn: -0.0391401	total: 1.47s	remaining: 1.1s
# 573:	learn: -0.0390573	total: 1.47s	remaining: 1.09s
# 574:	learn: -0.0390035	total: 1.47s	remaining: 1.09s
# 575:	learn: -0.0389561	total: 1.48s	remaining: 1.09s
# 576:	learn: -0.0389160	total: 1.48s	remaining: 1.08s
# 577:	learn: -0.0388166	total: 1.48s	remaining: 1.08s
# 578:	learn: -0.0387177	total: 1.48s	remaining: 1.08s
# 579:	learn: -0.0386192	total: 1.48s	remaining: 1.07s
# 580:	learn: -0.0385212	total: 1.48s	remaining: 1.07s
# 581:	learn: -0.0384410	total: 1.48s	remaining: 1.06s
# 582:	learn: -0.0383439	total: 1.49s	remaining: 1.06s
# 583:	learn: -0.0382990	total: 1.49s	remaining: 1.06s
# 584:	learn: -0.0382025	total: 1.49s	remaining: 1.05s
# 585:	learn: -0.0381066	total: 1.49s	remaining: 1.05s
# 586:	learn: -0.0380384	total: 1.49s	remaining: 1.05s
# 587:	learn: -0.0379432	total: 1.49s	remaining: 1.04s
# 588:	learn: -0.0378485	total: 1.49s	remaining: 1.04s
# 589:	learn: -0.0377979	total: 1.5s	remaining: 1.04s
# 590:	learn: -0.0377205	total: 1.5s	remaining: 1.04s
# 591:	learn: -0.0376435	total: 1.5s	remaining: 1.03s
# 592:	learn: -0.0375668	total: 1.5s	remaining: 1.03s
# 593:	learn: -0.0375295	total: 1.5s	remaining: 1.03s
# 594:	learn: -0.0374864	total: 1.5s	remaining: 1.02s
# 595:	learn: -0.0373939	total: 1.5s	remaining: 1.02s
# 596:	learn: -0.0373018	total: 1.5s	remaining: 1.02s
# 597:	learn: -0.0372396	total: 1.51s	remaining: 1.01s
# 598:	learn: -0.0372029	total: 1.51s	remaining: 1.01s
# 599:	learn: -0.0371279	total: 1.51s	remaining: 1.01s
# 600:	learn: -0.0370914	total: 1.51s	remaining: 1s
# 601:	learn: -0.0370008	total: 1.51s	remaining: 1s
# 602:	learn: -0.0369266	total: 1.52s	remaining: 998ms
# 603:	learn: -0.0368656	total: 1.52s	remaining: 995ms
# 604:	learn: -0.0367760	total: 1.52s	remaining: 992ms
# 605:	learn: -0.0367028	total: 1.52s	remaining: 989ms
# 606:	learn: -0.0366298	total: 1.52s	remaining: 986ms
# 607:	learn: -0.0365571	total: 1.52s	remaining: 982ms
# 608:	learn: -0.0364690	total: 1.52s	remaining: 979ms
# 609:	learn: -0.0363969	total: 1.52s	remaining: 975ms
# 610:	learn: -0.0363563	total: 1.53s	remaining: 973ms
# 611:	learn: -0.0362847	total: 1.53s	remaining: 969ms
# 612:	learn: -0.0361979	total: 1.53s	remaining: 966ms
# 613:	learn: -0.0361114	total: 1.53s	remaining: 963ms
# 614:	learn: -0.0360652	total: 1.53s	remaining: 960ms
# 615:	learn: -0.0359947	total: 1.53s	remaining: 956ms
# 616:	learn: -0.0359450	total: 1.54s	remaining: 954ms
# 617:	learn: -0.0358992	total: 1.54s	remaining: 951ms
# 618:	learn: -0.0358650	total: 1.54s	remaining: 948ms
# 619:	learn: -0.0357922	total: 1.54s	remaining: 945ms
# 620:	learn: -0.0357227	total: 1.54s	remaining: 941ms
# 621:	learn: -0.0356384	total: 1.54s	remaining: 938ms
# 622:	learn: -0.0356047	total: 1.54s	remaining: 935ms
# 623:	learn: -0.0355359	total: 1.55s	remaining: 932ms
# 624:	learn: -0.0354675	total: 1.55s	remaining: 929ms
# 625:	learn: -0.0353993	total: 1.55s	remaining: 926ms
# 626:	learn: -0.0353313	total: 1.55s	remaining: 923ms
# 627:	learn: -0.0352488	total: 1.55s	remaining: 919ms
# 628:	learn: -0.0351667	total: 1.55s	remaining: 916ms
# 629:	learn: -0.0350849	total: 1.55s	remaining: 913ms
# 630:	learn: -0.0350035	total: 1.55s	remaining: 910ms
# 631:	learn: -0.0349709	total: 1.56s	remaining: 907ms
# 632:	learn: -0.0348900	total: 1.56s	remaining: 904ms
# 633:	learn: -0.0348576	total: 1.56s	remaining: 901ms
# 634:	learn: -0.0348145	total: 1.56s	remaining: 898ms
# 635:	learn: -0.0347823	total: 1.56s	remaining: 896ms
# 636:	learn: -0.0347166	total: 1.57s	remaining: 893ms
# 637:	learn: -0.0346788	total: 1.57s	remaining: 890ms
# 638:	learn: -0.0346362	total: 1.57s	remaining: 888ms
# 639:	learn: -0.0345710	total: 1.57s	remaining: 885ms
# 640:	learn: -0.0345144	total: 1.57s	remaining: 882ms
# 641:	learn: -0.0344827	total: 1.58s	remaining: 881ms
# 642:	learn: -0.0344511	total: 1.58s	remaining: 879ms
# 643:	learn: -0.0344195	total: 1.58s	remaining: 877ms
# 644:	learn: -0.0343823	total: 1.59s	remaining: 874ms
# 645:	learn: -0.0343041	total: 1.59s	remaining: 872ms
# 646:	learn: -0.0342401	total: 1.59s	remaining: 869ms
# 647:	learn: -0.0341875	total: 1.59s	remaining: 866ms
# 648:	learn: -0.0341450	total: 1.6s	remaining: 864ms
# 649:	learn: -0.0340816	total: 1.6s	remaining: 861ms
# 650:	learn: -0.0340047	total: 1.6s	remaining: 858ms
# 651:	learn: -0.0339418	total: 1.6s	remaining: 854ms
# 652:	learn: -0.0338792	total: 1.6s	remaining: 851ms
# 653:	learn: -0.0338032	total: 1.6s	remaining: 848ms
# 654:	learn: -0.0337382	total: 1.6s	remaining: 846ms
# 655:	learn: -0.0336832	total: 1.61s	remaining: 843ms
# 656:	learn: -0.0336215	total: 1.61s	remaining: 840ms
# 657:	learn: -0.0335465	total: 1.61s	remaining: 837ms
# 658:	learn: -0.0334719	total: 1.61s	remaining: 834ms
# 659:	learn: -0.0334321	total: 1.61s	remaining: 831ms
# 660:	learn: -0.0333713	total: 1.61s	remaining: 828ms
# 661:	learn: -0.0333108	total: 1.61s	remaining: 825ms
# 662:	learn: -0.0332505	total: 1.62s	remaining: 821ms
# 663:	learn: -0.0331904	total: 1.62s	remaining: 818ms
# 664:	learn: -0.0331610	total: 1.62s	remaining: 816ms
# 665:	learn: -0.0331116	total: 1.62s	remaining: 813ms
# 666:	learn: -0.0330388	total: 1.62s	remaining: 810ms
# 667:	learn: -0.0329663	total: 1.62s	remaining: 807ms
# 668:	learn: -0.0328941	total: 1.62s	remaining: 804ms
# 669:	learn: -0.0328223	total: 1.63s	remaining: 801ms
# 670:	learn: -0.0327507	total: 1.63s	remaining: 798ms
# 671:	learn: -0.0327170	total: 1.63s	remaining: 795ms
# 672:	learn: -0.0326459	total: 1.63s	remaining: 792ms
# 673:	learn: -0.0325751	total: 1.63s	remaining: 789ms
# 674:	learn: -0.0325468	total: 1.63s	remaining: 787ms
# 675:	learn: -0.0324963	total: 1.64s	remaining: 784ms
# 676:	learn: -0.0324262	total: 1.64s	remaining: 781ms
# 677:	learn: -0.0323981	total: 1.64s	remaining: 779ms
# 678:	learn: -0.0323651	total: 1.64s	remaining: 776ms
# 679:	learn: -0.0323080	total: 1.64s	remaining: 773ms
# 680:	learn: -0.0322752	total: 1.65s	remaining: 771ms
# 681:	learn: -0.0322424	total: 1.65s	remaining: 768ms
# 682:	learn: -0.0321858	total: 1.65s	remaining: 765ms
# 683:	learn: -0.0321408	total: 1.65s	remaining: 763ms
# 684:	learn: -0.0320845	total: 1.65s	remaining: 760ms
# 685:	learn: -0.0320284	total: 1.65s	remaining: 757ms
# 686:	learn: -0.0319602	total: 1.65s	remaining: 754ms
# 687:	learn: -0.0319142	total: 1.66s	remaining: 751ms
# 688:	learn: -0.0318870	total: 1.66s	remaining: 748ms
# 689:	learn: -0.0318193	total: 1.66s	remaining: 745ms
# 690:	learn: -0.0317520	total: 1.66s	remaining: 742ms
# 691:	learn: -0.0316970	total: 1.66s	remaining: 740ms
# 692:	learn: -0.0316423	total: 1.66s	remaining: 737ms
# 693:	learn: -0.0315854	total: 1.66s	remaining: 734ms
# 694:	learn: -0.0315190	total: 1.67s	remaining: 731ms
# 695:	learn: -0.0314742	total: 1.67s	remaining: 728ms
# 696:	learn: -0.0314179	total: 1.67s	remaining: 725ms
# 697:	learn: -0.0313641	total: 1.67s	remaining: 722ms
# 698:	learn: -0.0312986	total: 1.67s	remaining: 719ms
# 699:	learn: -0.0312334	total: 1.67s	remaining: 716ms
# 700:	learn: -0.0311684	total: 1.67s	remaining: 714ms
# 701:	learn: -0.0311154	total: 1.67s	remaining: 711ms
# 702:	learn: -0.0310509	total: 1.68s	remaining: 708ms
# 703:	learn: -0.0309867	total: 1.68s	remaining: 705ms
# 704:	learn: -0.0309610	total: 1.68s	remaining: 703ms
# 705:	learn: -0.0309353	total: 1.68s	remaining: 701ms
# 706:	learn: -0.0308888	total: 1.68s	remaining: 698ms
# 707:	learn: -0.0308367	total: 1.69s	remaining: 695ms
# 708:	learn: -0.0307848	total: 1.69s	remaining: 692ms
# 709:	learn: -0.0307331	total: 1.69s	remaining: 689ms
# 710:	learn: -0.0306872	total: 1.69s	remaining: 687ms
# 711:	learn: -0.0306575	total: 1.69s	remaining: 684ms
# 712:	learn: -0.0306062	total: 1.69s	remaining: 681ms
# 713:	learn: -0.0305526	total: 1.69s	remaining: 679ms
# 714:	learn: -0.0304903	total: 1.7s	remaining: 676ms
# 715:	learn: -0.0304484	total: 1.7s	remaining: 673ms
# 716:	learn: -0.0304235	total: 1.7s	remaining: 670ms
# 717:	learn: -0.0303817	total: 1.7s	remaining: 668ms
# 718:	learn: -0.0303570	total: 1.7s	remaining: 666ms
# 719:	learn: -0.0303129	total: 1.71s	remaining: 663ms
# 720:	learn: -0.0302516	total: 1.71s	remaining: 661ms
# 721:	learn: -0.0302122	total: 1.71s	remaining: 658ms
# 722:	learn: -0.0301513	total: 1.71s	remaining: 655ms
# 723:	learn: -0.0301016	total: 1.71s	remaining: 653ms
# 724:	learn: -0.0300411	total: 1.71s	remaining: 650ms
# 725:	learn: -0.0299809	total: 1.71s	remaining: 647ms
# 726:	learn: -0.0299209	total: 1.72s	remaining: 644ms
# 727:	learn: -0.0298611	total: 1.72s	remaining: 641ms
# 728:	learn: -0.0298372	total: 1.72s	remaining: 639ms
# 729:	learn: -0.0298134	total: 1.72s	remaining: 636ms
# 730:	learn: -0.0297540	total: 1.72s	remaining: 634ms
# 731:	learn: -0.0297033	total: 1.72s	remaining: 631ms
# 732:	learn: -0.0296550	total: 1.72s	remaining: 628ms
# 733:	learn: -0.0296236	total: 1.73s	remaining: 626ms
# 734:	learn: -0.0295650	total: 1.73s	remaining: 623ms
# 735:	learn: -0.0295337	total: 1.73s	remaining: 620ms
# 736:	learn: -0.0295062	total: 1.73s	remaining: 618ms
# 737:	learn: -0.0294585	total: 1.73s	remaining: 615ms
# 738:	learn: -0.0294317	total: 1.73s	remaining: 613ms
# 739:	learn: -0.0293843	total: 1.74s	remaining: 610ms
# 740:	learn: -0.0293347	total: 1.74s	remaining: 607ms
# 741:	learn: -0.0292877	total: 1.74s	remaining: 605ms
# 742:	learn: -0.0292407	total: 1.74s	remaining: 602ms
# 743:	learn: -0.0291836	total: 1.74s	remaining: 599ms
# 744:	learn: -0.0291420	total: 1.74s	remaining: 596ms
# 745:	learn: -0.0290956	total: 1.74s	remaining: 594ms
# 746:	learn: -0.0290389	total: 1.74s	remaining: 591ms
# 747:	learn: -0.0289905	total: 1.75s	remaining: 588ms
# 748:	learn: -0.0289343	total: 1.75s	remaining: 585ms
# 749:	learn: -0.0288863	total: 1.75s	remaining: 583ms
# 750:	learn: -0.0288305	total: 1.75s	remaining: 580ms
# 751:	learn: -0.0287748	total: 1.75s	remaining: 577ms
# 752:	learn: -0.0287273	total: 1.75s	remaining: 575ms
# 753:	learn: -0.0286978	total: 1.76s	remaining: 573ms
# 754:	learn: -0.0286623	total: 1.76s	remaining: 571ms
# 755:	learn: -0.0286173	total: 1.76s	remaining: 568ms
# 756:	learn: -0.0285724	total: 1.76s	remaining: 566ms
# 757:	learn: -0.0285326	total: 1.76s	remaining: 563ms
# 758:	learn: -0.0284781	total: 1.76s	remaining: 561ms
# 759:	learn: -0.0284529	total: 1.77s	remaining: 559ms
# 760:	learn: -0.0284239	total: 1.77s	remaining: 556ms
# 761:	learn: -0.0283950	total: 1.77s	remaining: 554ms
# 762:	learn: -0.0283734	total: 1.78s	remaining: 552ms
# 763:	learn: -0.0283484	total: 1.78s	remaining: 550ms
# 764:	learn: -0.0283092	total: 1.78s	remaining: 547ms
# 765:	learn: -0.0282653	total: 1.78s	remaining: 545ms
# 766:	learn: -0.0282438	total: 1.78s	remaining: 542ms
# 767:	learn: -0.0281904	total: 1.79s	remaining: 540ms
# 768:	learn: -0.0281372	total: 1.79s	remaining: 537ms
# 769:	learn: -0.0281121	total: 1.79s	remaining: 535ms
# 770:	learn: -0.0280687	total: 1.79s	remaining: 532ms
# 771:	learn: -0.0280476	total: 1.79s	remaining: 530ms
# 772:	learn: -0.0279949	total: 1.79s	remaining: 527ms
# 773:	learn: -0.0279610	total: 1.8s	remaining: 525ms
# 774:	learn: -0.0279363	total: 1.8s	remaining: 523ms
# 775:	learn: -0.0278935	total: 1.8s	remaining: 520ms
# 776:	learn: -0.0278656	total: 1.8s	remaining: 517ms
# 777:	learn: -0.0278378	total: 1.8s	remaining: 515ms
# 778:	learn: -0.0277858	total: 1.8s	remaining: 512ms
# 779:	learn: -0.0277435	total: 1.81s	remaining: 510ms
# 780:	learn: -0.0277012	total: 1.81s	remaining: 507ms
# 781:	learn: -0.0276498	total: 1.81s	remaining: 504ms
# 782:	learn: -0.0276292	total: 1.81s	remaining: 502ms
# 783:	learn: -0.0275919	total: 1.81s	remaining: 500ms
# 784:	learn: -0.0275409	total: 1.81s	remaining: 497ms
# 785:	learn: -0.0274900	total: 1.82s	remaining: 495ms
# 786:	learn: -0.0274393	total: 1.82s	remaining: 492ms
# 787:	learn: -0.0274191	total: 1.82s	remaining: 490ms
# 788:	learn: -0.0273921	total: 1.82s	remaining: 487ms
# 789:	learn: -0.0273561	total: 1.82s	remaining: 485ms
# 790:	learn: -0.0273150	total: 1.82s	remaining: 482ms
# 791:	learn: -0.0272883	total: 1.83s	remaining: 480ms
# 792:	learn: -0.0272383	total: 1.83s	remaining: 477ms
# 793:	learn: -0.0271885	total: 1.83s	remaining: 475ms
# 794:	learn: -0.0271561	total: 1.83s	remaining: 472ms
# 795:	learn: -0.0271156	total: 1.83s	remaining: 470ms
# 796:	learn: -0.0270923	total: 1.83s	remaining: 467ms
# 797:	learn: -0.0270431	total: 1.83s	remaining: 465ms
# 798:	learn: -0.0270110	total: 1.84s	remaining: 462ms
# 799:	learn: -0.0269795	total: 1.84s	remaining: 460ms
# 800:	learn: -0.0269599	total: 1.84s	remaining: 457ms
# 801:	learn: -0.0269200	total: 1.84s	remaining: 455ms
# 802:	learn: -0.0268801	total: 1.84s	remaining: 452ms
# 803:	learn: -0.0268403	total: 1.84s	remaining: 450ms
# 804:	learn: -0.0268210	total: 1.85s	remaining: 448ms
# 805:	learn: -0.0267727	total: 1.85s	remaining: 445ms
# 806:	learn: -0.0267314	total: 1.85s	remaining: 443ms
# 807:	learn: -0.0267058	total: 1.85s	remaining: 440ms
# 808:	learn: -0.0266866	total: 1.85s	remaining: 438ms
# 809:	learn: -0.0266558	total: 1.86s	remaining: 436ms
# 810:	learn: -0.0266211	total: 1.86s	remaining: 433ms
# 811:	learn: -0.0265821	total: 1.86s	remaining: 431ms
# 812:	learn: -0.0265346	total: 1.86s	remaining: 428ms
# 813:	learn: -0.0264958	total: 1.86s	remaining: 425ms
# 814:	learn: -0.0264487	total: 1.86s	remaining: 423ms
# 815:	learn: -0.0264101	total: 1.86s	remaining: 420ms
# 816:	learn: -0.0263717	total: 1.86s	remaining: 418ms
# 817:	learn: -0.0263377	total: 1.87s	remaining: 415ms
# 818:	learn: -0.0262995	total: 1.87s	remaining: 413ms
# 819:	learn: -0.0262530	total: 1.87s	remaining: 410ms
# 820:	learn: -0.0262067	total: 1.87s	remaining: 408ms
# 821:	learn: -0.0261754	total: 1.87s	remaining: 405ms
# 822:	learn: -0.0261537	total: 1.87s	remaining: 403ms
# 823:	learn: -0.0261077	total: 1.88s	remaining: 401ms
# 824:	learn: -0.0260894	total: 1.88s	remaining: 398ms
# 825:	learn: -0.0260519	total: 1.88s	remaining: 396ms
# 826:	learn: -0.0260145	total: 1.88s	remaining: 393ms
# 827:	learn: -0.0259930	total: 1.88s	remaining: 391ms
# 828:	learn: -0.0259558	total: 1.88s	remaining: 389ms
# 829:	learn: -0.0259104	total: 1.88s	remaining: 386ms
# 830:	learn: -0.0258735	total: 1.89s	remaining: 384ms
# 831:	learn: -0.0258554	total: 1.89s	remaining: 381ms
# 832:	learn: -0.0258169	total: 1.89s	remaining: 379ms
# 833:	learn: -0.0257801	total: 1.89s	remaining: 376ms
# 834:	learn: -0.0257418	total: 1.89s	remaining: 374ms
# 835:	learn: -0.0257053	total: 1.89s	remaining: 371ms
# 836:	learn: -0.0256689	total: 1.89s	remaining: 369ms
# 837:	learn: -0.0256245	total: 1.9s	remaining: 367ms
# 838:	learn: -0.0255804	total: 1.9s	remaining: 364ms
# 839:	learn: -0.0255363	total: 1.9s	remaining: 362ms
# 840:	learn: -0.0254924	total: 1.9s	remaining: 359ms
# 841:	learn: -0.0254487	total: 1.9s	remaining: 357ms
# 842:	learn: -0.0254130	total: 1.9s	remaining: 354ms
# 843:	learn: -0.0253925	total: 1.9s	remaining: 352ms
# 844:	learn: -0.0253569	total: 1.91s	remaining: 350ms
# 845:	learn: -0.0253338	total: 1.91s	remaining: 347ms
# 846:	learn: -0.0252985	total: 1.91s	remaining: 345ms
# 847:	learn: -0.0252786	total: 1.91s	remaining: 343ms
# 848:	learn: -0.0252613	total: 1.91s	remaining: 340ms
# 849:	learn: -0.0252262	total: 1.92s	remaining: 338ms
# 850:	learn: -0.0251894	total: 1.92s	remaining: 336ms
# 851:	learn: -0.0251692	total: 1.92s	remaining: 333ms
# 852:	learn: -0.0251343	total: 1.92s	remaining: 331ms
# 853:	learn: -0.0251173	total: 1.92s	remaining: 329ms
# 854:	learn: -0.0250972	total: 1.92s	remaining: 326ms
# 855:	learn: -0.0250625	total: 1.93s	remaining: 324ms
# 856:	learn: -0.0250456	total: 1.93s	remaining: 322ms
# 857:	learn: -0.0250153	total: 1.93s	remaining: 319ms
# 858:	learn: -0.0249791	total: 1.93s	remaining: 317ms
# 859:	learn: -0.0249447	total: 1.93s	remaining: 315ms
# 860:	learn: -0.0249250	total: 1.94s	remaining: 312ms
# 861:	learn: -0.0248892	total: 1.94s	remaining: 310ms
# 862:	learn: -0.0248551	total: 1.94s	remaining: 308ms
# 863:	learn: -0.0248210	total: 1.94s	remaining: 305ms
# 864:	learn: -0.0247968	total: 1.94s	remaining: 303ms
# 865:	learn: -0.0247613	total: 1.94s	remaining: 301ms
# 866:	learn: -0.0247274	total: 1.95s	remaining: 299ms
# 867:	learn: -0.0246937	total: 1.95s	remaining: 296ms
# 868:	learn: -0.0246747	total: 1.95s	remaining: 294ms
# 869:	learn: -0.0246411	total: 1.95s	remaining: 292ms
# 870:	learn: -0.0246002	total: 1.95s	remaining: 290ms
# 871:	learn: -0.0245838	total: 1.96s	remaining: 287ms
# 872:	learn: -0.0245431	total: 1.96s	remaining: 285ms
# 873:	learn: -0.0245194	total: 1.96s	remaining: 283ms
# 874:	learn: -0.0245002	total: 1.96s	remaining: 281ms
# 875:	learn: -0.0244671	total: 1.97s	remaining: 278ms
# 876:	learn: -0.0244456	total: 1.97s	remaining: 276ms
# 877:	learn: -0.0244126	total: 1.97s	remaining: 274ms
# 878:	learn: -0.0243724	total: 1.97s	remaining: 271ms
# 879:	learn: -0.0243453	total: 1.97s	remaining: 269ms
# 880:	learn: -0.0243183	total: 1.97s	remaining: 267ms
# 881:	learn: -0.0242857	total: 1.98s	remaining: 264ms
# 882:	learn: -0.0242532	total: 1.98s	remaining: 262ms
# 883:	learn: -0.0242207	total: 1.98s	remaining: 260ms
# 884:	learn: -0.0241811	total: 1.98s	remaining: 257ms
# 885:	learn: -0.0241489	total: 1.98s	remaining: 255ms
# 886:	learn: -0.0241167	total: 1.98s	remaining: 252ms
# 887:	learn: -0.0240774	total: 1.98s	remaining: 250ms
# 888:	learn: -0.0240590	total: 1.99s	remaining: 248ms
# 889:	learn: -0.0240406	total: 1.99s	remaining: 246ms
# 890:	learn: -0.0240087	total: 1.99s	remaining: 243ms
# 891:	learn: -0.0239824	total: 1.99s	remaining: 241ms
# 892:	learn: -0.0239507	total: 1.99s	remaining: 239ms
# 893:	learn: -0.0239175	total: 1.99s	remaining: 236ms
# 894:	learn: -0.0238859	total: 1.99s	remaining: 234ms
# 895:	learn: -0.0238474	total: 2s	remaining: 232ms
# 896:	learn: -0.0238194	total: 2s	remaining: 229ms
# 897:	learn: -0.0237881	total: 2s	remaining: 227ms
# 898:	learn: -0.0237704	total: 2s	remaining: 225ms
# 899:	learn: -0.0237551	total: 2s	remaining: 223ms
# 900:	learn: -0.0237240	total: 2s	remaining: 220ms
# 901:	learn: -0.0236929	total: 2s	remaining: 218ms
# 902:	learn: -0.0236673	total: 2.01s	remaining: 216ms
# 903:	learn: -0.0236365	total: 2.01s	remaining: 213ms
# 904:	learn: -0.0236163	total: 2.01s	remaining: 211ms
# 905:	learn: -0.0236012	total: 2.01s	remaining: 209ms
# 906:	learn: -0.0235705	total: 2.01s	remaining: 206ms
# 907:	learn: -0.0235431	total: 2.01s	remaining: 204ms
# 908:	learn: -0.0235110	total: 2.02s	remaining: 202ms
# 909:	learn: -0.0234937	total: 2.02s	remaining: 200ms
# ...
# 700:	learn: -0.0240067	total: 1.39s	remaining: 595ms
# 701:	learn: -0.0239680	total: 1.4s	remaining: 592ms
# 702:	learn: -0.0239294	total: 1.4s	remaining: 590ms
# 703:	learn: -0.0238909	total: 1.4s	remaining: 588ms
# 704:	learn: -0.0238526	total: 1.4s	remaining: 585ms
# 705:	learn: -0.0238200	total: 1.4s	remaining: 583ms
# 706:	learn: -0.0237818	total: 1.4s	remaining: 581ms
# 707:	learn: -0.0237438	total: 1.4s	remaining: 579ms
# 708:	learn: -0.0237169	total: 1.41s	remaining: 578ms
# 709:	learn: -0.0236847	total: 1.41s	remaining: 576ms
# 710:	learn: -0.0236576	total: 1.41s	remaining: 574ms
# 711:	learn: -0.0236255	total: 1.41s	remaining: 571ms
# 712:	learn: -0.0235880	total: 1.41s	remaining: 569ms
# 713:	learn: -0.0235506	total: 1.42s	remaining: 567ms
# 714:	learn: -0.0235189	total: 1.42s	remaining: 565ms
# 715:	learn: -0.0234817	total: 1.42s	remaining: 562ms
# 716:	learn: -0.0234446	total: 1.42s	remaining: 560ms
# 717:	learn: -0.0234077	total: 1.42s	remaining: 558ms
# 718:	learn: -0.0233763	total: 1.42s	remaining: 557ms
# 719:	learn: -0.0233395	total: 1.43s	remaining: 554ms
# 720:	learn: -0.0233029	total: 1.43s	remaining: 552ms
# 721:	learn: -0.0232718	total: 1.43s	remaining: 550ms
# 722:	learn: -0.0232407	total: 1.43s	remaining: 548ms
# 723:	learn: -0.0232044	total: 1.43s	remaining: 546ms
# 724:	learn: -0.0231682	total: 1.43s	remaining: 544ms
# 725:	learn: -0.0231321	total: 1.44s	remaining: 542ms
# 726:	learn: -0.0231014	total: 1.44s	remaining: 540ms
# 727:	learn: -0.0230655	total: 1.44s	remaining: 538ms
# 728:	learn: -0.0230297	total: 1.44s	remaining: 536ms
# 729:	learn: -0.0229994	total: 1.44s	remaining: 534ms
# 730:	learn: -0.0229638	total: 1.44s	remaining: 531ms
# 731:	learn: -0.0229283	total: 1.45s	remaining: 529ms
# 732:	learn: -0.0228929	total: 1.45s	remaining: 527ms
# 733:	learn: -0.0228629	total: 1.45s	remaining: 525ms
# 734:	learn: -0.0228379	total: 1.45s	remaining: 523ms
# 735:	learn: -0.0228080	total: 1.45s	remaining: 521ms
# 736:	learn: -0.0227782	total: 1.45s	remaining: 519ms
# 737:	learn: -0.0227534	total: 1.45s	remaining: 517ms
# 738:	learn: -0.0227231	total: 1.46s	remaining: 514ms
# 739:	learn: -0.0226985	total: 1.46s	remaining: 512ms
# 740:	learn: -0.0226638	total: 1.46s	remaining: 510ms
# 741:	learn: -0.0226292	total: 1.46s	remaining: 508ms
# 742:	learn: -0.0225947	total: 1.46s	remaining: 506ms
# 743:	learn: -0.0225603	total: 1.46s	remaining: 504ms
# 744:	learn: -0.0225260	total: 1.47s	remaining: 502ms
# 745:	learn: -0.0224918	total: 1.47s	remaining: 500ms
# 746:	learn: -0.0224578	total: 1.47s	remaining: 498ms
# 747:	learn: -0.0224238	total: 1.47s	remaining: 496ms
# 748:	learn: -0.0223899	total: 1.47s	remaining: 494ms
# 749:	learn: -0.0223561	total: 1.48s	remaining: 492ms
# 750:	learn: -0.0223225	total: 1.48s	remaining: 490ms
# 751:	learn: -0.0222889	total: 1.48s	remaining: 488ms
# 752:	learn: -0.0222554	total: 1.48s	remaining: 486ms
# 753:	learn: -0.0222370	total: 1.49s	remaining: 485ms
# 754:	learn: -0.0222037	total: 1.49s	remaining: 483ms
# 755:	learn: -0.0221704	total: 1.49s	remaining: 480ms
# 756:	learn: -0.0221422	total: 1.49s	remaining: 478ms
# 757:	learn: -0.0221092	total: 1.49s	remaining: 476ms
# 758:	learn: -0.0220762	total: 1.49s	remaining: 474ms
# 759:	learn: -0.0220434	total: 1.49s	remaining: 472ms
# 760:	learn: -0.0220106	total: 1.5s	remaining: 470ms
# 761:	learn: -0.0219779	total: 1.5s	remaining: 468ms
# 762:	learn: -0.0219454	total: 1.5s	remaining: 466ms
# 763:	learn: -0.0219177	total: 1.5s	remaining: 464ms
# 764:	learn: -0.0218853	total: 1.5s	remaining: 462ms
# 765:	learn: -0.0218530	total: 1.5s	remaining: 460ms
# 766:	learn: -0.0218208	total: 1.51s	remaining: 458ms
# 767:	learn: -0.0217887	total: 1.51s	remaining: 456ms
# 768:	learn: -0.0217567	total: 1.51s	remaining: 454ms
# 769:	learn: -0.0217248	total: 1.51s	remaining: 452ms
# 770:	learn: -0.0217074	total: 1.52s	remaining: 450ms
# 771:	learn: -0.0216757	total: 1.52s	remaining: 448ms
# 772:	learn: -0.0216440	total: 1.52s	remaining: 446ms
# 773:	learn: -0.0216171	total: 1.52s	remaining: 444ms
# 774:	learn: -0.0215902	total: 1.52s	remaining: 442ms
# 775:	learn: -0.0215587	total: 1.52s	remaining: 440ms
# 776:	learn: -0.0215321	total: 1.53s	remaining: 438ms
# 777:	learn: -0.0215054	total: 1.53s	remaining: 437ms
# 778:	learn: -0.0214742	total: 1.53s	remaining: 434ms
# 779:	learn: -0.0214431	total: 1.53s	remaining: 432ms
# 780:	learn: -0.0214120	total: 1.53s	remaining: 430ms
# 781:	learn: -0.0213857	total: 1.54s	remaining: 428ms
# 782:	learn: -0.0213548	total: 1.54s	remaining: 426ms
# 783:	learn: -0.0213240	total: 1.54s	remaining: 424ms
# 784:	learn: -0.0212933	total: 1.54s	remaining: 422ms
# 785:	learn: -0.0212627	total: 1.54s	remaining: 420ms
# 786:	learn: -0.0212322	total: 1.54s	remaining: 418ms
# 787:	learn: -0.0212106	total: 1.55s	remaining: 416ms
# 788:	learn: -0.0211802	total: 1.55s	remaining: 414ms
# 789:	learn: -0.0211544	total: 1.55s	remaining: 412ms
# 790:	learn: -0.0211329	total: 1.55s	remaining: 410ms
# 791:	learn: -0.0211028	total: 1.55s	remaining: 408ms
# 792:	learn: -0.0210727	total: 1.56s	remaining: 406ms
# 793:	learn: -0.0210471	total: 1.56s	remaining: 405ms
# 794:	learn: -0.0210172	total: 1.56s	remaining: 403ms
# 795:	learn: -0.0209874	total: 1.56s	remaining: 400ms
# 796:	learn: -0.0209576	total: 1.56s	remaining: 398ms
# 797:	learn: -0.0209324	total: 1.56s	remaining: 396ms
# 798:	learn: -0.0209027	total: 1.57s	remaining: 394ms
# 799:	learn: -0.0208732	total: 1.57s	remaining: 392ms
# 800:	learn: -0.0208438	total: 1.57s	remaining: 390ms
# 801:	learn: -0.0208144	total: 1.57s	remaining: 388ms
# 802:	learn: -0.0207851	total: 1.57s	remaining: 386ms
# 803:	learn: -0.0207559	total: 1.57s	remaining: 384ms
# 804:	learn: -0.0207311	total: 1.58s	remaining: 382ms
# 805:	learn: -0.0207021	total: 1.58s	remaining: 380ms
# 806:	learn: -0.0206774	total: 1.58s	remaining: 378ms
# 807:	learn: -0.0206485	total: 1.58s	remaining: 376ms
# 808:	learn: -0.0206197	total: 1.58s	remaining: 373ms
# 809:	learn: -0.0205909	total: 1.58s	remaining: 371ms
# 810:	learn: -0.0205665	total: 1.58s	remaining: 369ms
# 811:	learn: -0.0205422	total: 1.59s	remaining: 367ms
# 812:	learn: -0.0205137	total: 1.59s	remaining: 365ms
# 813:	learn: -0.0204905	total: 1.59s	remaining: 363ms
# 814:	learn: -0.0204621	total: 1.59s	remaining: 361ms
# 815:	learn: -0.0204380	total: 1.59s	remaining: 359ms
# 816:	learn: -0.0204139	total: 1.59s	remaining: 357ms
# 817:	learn: -0.0203899	total: 1.59s	remaining: 355ms
# 818:	learn: -0.0203660	total: 1.6s	remaining: 353ms
# 819:	learn: -0.0203379	total: 1.6s	remaining: 351ms
# 820:	learn: -0.0203099	total: 1.6s	remaining: 349ms
# 821:	learn: -0.0202898	total: 1.6s	remaining: 347ms
# 822:	learn: -0.0202620	total: 1.6s	remaining: 345ms
# 823:	learn: -0.0202342	total: 1.61s	remaining: 343ms
# 824:	learn: -0.0202106	total: 1.61s	remaining: 341ms
# 825:	learn: -0.0201830	total: 1.61s	remaining: 339ms
# 826:	learn: -0.0201595	total: 1.61s	remaining: 337ms
# 827:	learn: -0.0201320	total: 1.61s	remaining: 335ms
# 828:	learn: -0.0201087	total: 1.61s	remaining: 333ms
# 829:	learn: -0.0200854	total: 1.62s	remaining: 331ms
# 830:	learn: -0.0200631	total: 1.62s	remaining: 329ms
# 831:	learn: -0.0200399	total: 1.62s	remaining: 327ms
# 832:	learn: -0.0200128	total: 1.62s	remaining: 325ms
# 833:	learn: -0.0199856	total: 1.62s	remaining: 323ms
# 834:	learn: -0.0199586	total: 1.63s	remaining: 321ms
# 835:	learn: -0.0199356	total: 1.63s	remaining: 319ms
# 836:	learn: -0.0199127	total: 1.63s	remaining: 317ms
# 837:	learn: -0.0198859	total: 1.63s	remaining: 315ms
# 838:	learn: -0.0198591	total: 1.63s	remaining: 313ms
# 839:	learn: -0.0198324	total: 1.63s	remaining: 311ms
# 840:	learn: -0.0198107	total: 1.64s	remaining: 309ms
# 841:	learn: -0.0197841	total: 1.64s	remaining: 307ms
# 842:	learn: -0.0197576	total: 1.64s	remaining: 305ms
# 843:	learn: -0.0197351	total: 1.64s	remaining: 303ms
# 844:	learn: -0.0197087	total: 1.64s	remaining: 301ms
# 845:	learn: -0.0196863	total: 1.64s	remaining: 299ms
# 846:	learn: -0.0196600	total: 1.64s	remaining: 297ms
# 847:	learn: -0.0196378	total: 1.65s	remaining: 295ms
# 848:	learn: -0.0196116	total: 1.65s	remaining: 293ms
# 849:	learn: -0.0195856	total: 1.65s	remaining: 291ms
# 850:	learn: -0.0195634	total: 1.65s	remaining: 289ms
# 851:	learn: -0.0195414	total: 1.65s	remaining: 287ms
# 852:	learn: -0.0195217	total: 1.66s	remaining: 285ms
# 853:	learn: -0.0194958	total: 1.66s	remaining: 283ms
# 854:	learn: -0.0194739	total: 1.66s	remaining: 281ms
# 855:	learn: -0.0194520	total: 1.66s	remaining: 279ms
# 856:	learn: -0.0194302	total: 1.66s	remaining: 278ms
# 857:	learn: -0.0194046	total: 1.67s	remaining: 276ms
# 858:	learn: -0.0193791	total: 1.67s	remaining: 274ms
# 859:	learn: -0.0193536	total: 1.67s	remaining: 272ms
# 860:	learn: -0.0193320	total: 1.67s	remaining: 270ms
# 861:	learn: -0.0193105	total: 1.67s	remaining: 268ms
# 862:	learn: -0.0192852	total: 1.68s	remaining: 266ms
# 863:	learn: -0.0192633	total: 1.68s	remaining: 264ms
# 864:	learn: -0.0192419	total: 1.68s	remaining: 262ms
# 865:	learn: -0.0192240	total: 1.68s	remaining: 260ms
# 866:	learn: -0.0192027	total: 1.68s	remaining: 258ms
# 867:	learn: -0.0191814	total: 1.69s	remaining: 256ms
# 868:	learn: -0.0191611	total: 1.69s	remaining: 254ms
# 869:	learn: -0.0191362	total: 1.69s	remaining: 252ms
# 870:	learn: -0.0191114	total: 1.69s	remaining: 251ms
# 871:	learn: -0.0190938	total: 1.69s	remaining: 249ms
# 872:	learn: -0.0190727	total: 1.7s	remaining: 247ms
# 873:	learn: -0.0190517	total: 1.7s	remaining: 245ms
# 874:	learn: -0.0190317	total: 1.7s	remaining: 243ms
# 875:	learn: -0.0190071	total: 1.7s	remaining: 241ms
# 876:	learn: -0.0189826	total: 1.7s	remaining: 239ms
# 877:	learn: -0.0189581	total: 1.7s	remaining: 237ms
# 878:	learn: -0.0189374	total: 1.71s	remaining: 235ms
# 879:	learn: -0.0189201	total: 1.71s	remaining: 233ms
# 880:	learn: -0.0188994	total: 1.71s	remaining: 231ms
# 881:	learn: -0.0188788	total: 1.71s	remaining: 229ms
# 882:	learn: -0.0188546	total: 1.71s	remaining: 227ms
# 883:	learn: -0.0188305	total: 1.71s	remaining: 225ms
# 884:	learn: -0.0188109	total: 1.72s	remaining: 223ms
# 885:	learn: -0.0187904	total: 1.72s	remaining: 221ms
# 886:	learn: -0.0187665	total: 1.72s	remaining: 219ms
# 887:	learn: -0.0187461	total: 1.72s	remaining: 217ms
# 888:	learn: -0.0187267	total: 1.72s	remaining: 215ms
# 889:	learn: -0.0187029	total: 1.72s	remaining: 213ms
# 890:	learn: -0.0186792	total: 1.73s	remaining: 211ms
# 891:	learn: -0.0186555	total: 1.73s	remaining: 209ms
# 892:	learn: -0.0186318	total: 1.73s	remaining: 207ms
# 893:	learn: -0.0186083	total: 1.73s	remaining: 205ms
# 894:	learn: -0.0185847	total: 1.73s	remaining: 203ms
# 895:	learn: -0.0185656	total: 1.73s	remaining: 201ms
# 896:	learn: -0.0185457	total: 1.73s	remaining: 199ms
# 897:	learn: -0.0185255	total: 1.73s	remaining: 197ms
# 898:	learn: -0.0185021	total: 1.74s	remaining: 195ms
# 899:	learn: -0.0184789	total: 1.74s	remaining: 193ms
# 900:	learn: -0.0184600	total: 1.74s	remaining: 191ms
# 901:	learn: -0.0184412	total: 1.74s	remaining: 189ms
# 902:	learn: -0.0184180	total: 1.74s	remaining: 187ms
# 903:	learn: -0.0183950	total: 1.75s	remaining: 185ms
# 904:	learn: -0.0183754	total: 1.75s	remaining: 183ms
# 905:	learn: -0.0183525	total: 1.75s	remaining: 181ms
# 906:	learn: -0.0183296	total: 1.75s	remaining: 179ms
# 907:	learn: -0.0183068	total: 1.75s	remaining: 178ms
# 908:	learn: -0.0182840	total: 1.75s	remaining: 176ms
# 909:	learn: -0.0182655	total: 1.75s	remaining: 174ms
# 910:	learn: -0.0182428	total: 1.76s	remaining: 172ms
# 911:	learn: -0.0182202	total: 1.76s	remaining: 170ms
# 912:	learn: -0.0182018	total: 1.76s	remaining: 168ms
# 913:	learn: -0.0181847	total: 1.76s	remaining: 166ms
# 914:	learn: -0.0181656	total: 1.76s	remaining: 164ms
# 915:	learn: -0.0181432	total: 1.76s	remaining: 162ms
# 916:	learn: -0.0181241	total: 1.77s	remaining: 160ms
# 917:	learn: -0.0181051	total: 1.77s	remaining: 158ms
# 918:	learn: -0.0180862	total: 1.77s	remaining: 156ms
# 919:	learn: -0.0180681	total: 1.77s	remaining: 154ms
# 920:	learn: -0.0180459	total: 1.77s	remaining: 152ms
# 921:	learn: -0.0180238	total: 1.78s	remaining: 150ms
# 922:	learn: -0.0180017	total: 1.78s	remaining: 148ms
# 923:	learn: -0.0179829	total: 1.78s	remaining: 146ms
# 924:	learn: -0.0179609	total: 1.78s	remaining: 144ms
# 925:	learn: -0.0179390	total: 1.78s	remaining: 143ms
# 926:	learn: -0.0179171	total: 1.78s	remaining: 141ms
# 927:	learn: -0.0178986	total: 1.79s	remaining: 139ms
# 928:	learn: -0.0178768	total: 1.79s	remaining: 137ms
# 929:	learn: -0.0178550	total: 1.79s	remaining: 135ms
# 930:	learn: -0.0178334	total: 1.79s	remaining: 133ms
# 931:	learn: -0.0178117	total: 1.79s	remaining: 131ms
# 932:	learn: -0.0177933	total: 1.79s	remaining: 129ms
# 933:	learn: -0.0177718	total: 1.79s	remaining: 127ms
# 934:	learn: -0.0177535	total: 1.8s	remaining: 125ms
# 935:	learn: -0.0177383	total: 1.8s	remaining: 123ms
# 936:	learn: -0.0177169	total: 1.8s	remaining: 121ms
# 937:	learn: -0.0176987	total: 1.8s	remaining: 119ms
# 938:	learn: -0.0176774	total: 1.81s	remaining: 117ms
# 939:	learn: -0.0176594	total: 1.81s	remaining: 115ms
# 940:	learn: -0.0176409	total: 1.81s	remaining: 113ms
# 941:	learn: -0.0176198	total: 1.81s	remaining: 112ms
# 942:	learn: -0.0176018	total: 1.81s	remaining: 110ms
# 943:	learn: -0.0175807	total: 1.82s	remaining: 108ms
# 944:	learn: -0.0175629	total: 1.82s	remaining: 106ms
# 945:	learn: -0.0175450	total: 1.82s	remaining: 104ms
# 946:	learn: -0.0175241	total: 1.82s	remaining: 102ms
# 947:	learn: -0.0175092	total: 1.82s	remaining: 100ms
# 948:	learn: -0.0174915	total: 1.82s	remaining: 98ms
# 949:	learn: -0.0174707	total: 1.82s	remaining: 96.1ms
# 950:	learn: -0.0174538	total: 1.83s	remaining: 94.2ms
# 951:	learn: -0.0174391	total: 1.83s	remaining: 92.3ms
# 952:	learn: -0.0174183	total: 1.83s	remaining: 90.4ms
# 953:	learn: -0.0174050	total: 1.83s	remaining: 88.5ms
# 954:	learn: -0.0173875	total: 1.84s	remaining: 86.5ms
# 955:	learn: -0.0173669	total: 1.84s	remaining: 84.6ms
# 956:	learn: -0.0173494	total: 1.84s	remaining: 82.6ms
# 957:	learn: -0.0173319	total: 1.84s	remaining: 80.7ms
# 958:	learn: -0.0173115	total: 1.84s	remaining: 78.8ms
# 959:	learn: -0.0172911	total: 1.84s	remaining: 76.9ms
# 960:	learn: -0.0172737	total: 1.85s	remaining: 75ms
# 961:	learn: -0.0172591	total: 1.85s	remaining: 73.1ms
# 962:	learn: -0.0172418	total: 1.85s	remaining: 71.2ms
# 963:	learn: -0.0172216	total: 1.85s	remaining: 69.2ms
# 964:	learn: -0.0172043	total: 1.86s	remaining: 67.4ms
# 965:	learn: -0.0171872	total: 1.86s	remaining: 65.5ms
# 966:	learn: -0.0171700	total: 1.86s	remaining: 63.6ms
# 967:	learn: -0.0171530	total: 1.86s	remaining: 61.6ms
# 968:	learn: -0.0171329	total: 1.87s	remaining: 59.7ms
# 969:	learn: -0.0171159	total: 1.87s	remaining: 57.8ms
# 970:	learn: -0.0170960	total: 1.87s	remaining: 55.8ms
# 971:	learn: -0.0170818	total: 1.87s	remaining: 53.9ms
# 972:	learn: -0.0170619	total: 1.87s	remaining: 52ms
# 973:	learn: -0.0170451	total: 1.88s	remaining: 50.1ms
# 974:	learn: -0.0170282	total: 1.88s	remaining: 48.1ms
# 975:	learn: -0.0170085	total: 1.88s	remaining: 46.2ms
# 976:	learn: -0.0169917	total: 1.88s	remaining: 44.3ms
# 977:	learn: -0.0169720	total: 1.88s	remaining: 42.3ms
# 978:	learn: -0.0169553	total: 1.88s	remaining: 40.4ms
# 979:	learn: -0.0169386	total: 1.88s	remaining: 38.5ms
# 980:	learn: -0.0169191	total: 1.89s	remaining: 36.5ms
# 981:	learn: -0.0168996	total: 1.89s	remaining: 34.6ms
# 982:	learn: -0.0168830	total: 1.89s	remaining: 32.7ms
# 983:	learn: -0.0168636	total: 1.89s	remaining: 30.8ms
# 984:	learn: -0.0168442	total: 1.89s	remaining: 28.8ms
# 985:	learn: -0.0168248	total: 1.89s	remaining: 26.9ms
# 986:	learn: -0.0168055	total: 1.9s	remaining: 25ms
# 987:	learn: -0.0167892	total: 1.9s	remaining: 23.1ms
# 988:	learn: -0.0167755	total: 1.9s	remaining: 21.1ms
# 989:	learn: -0.0167609	total: 1.9s	remaining: 19.2ms
# 990:	learn: -0.0167418	total: 1.9s	remaining: 17.3ms
# 991:	learn: -0.0167255	total: 1.91s	remaining: 15.4ms
# 992:	learn: -0.0167064	total: 1.91s	remaining: 13.5ms
# 993:	learn: -0.0166903	total: 1.91s	remaining: 11.5ms
# 994:	learn: -0.0166713	total: 1.91s	remaining: 9.61ms
# 995:	learn: -0.0166578	total: 1.91s	remaining: 7.68ms
# 996:	learn: -0.0166417	total: 1.91s	remaining: 5.76ms
# 997:	learn: -0.0166257	total: 1.92s	remaining: 3.84ms
# 998:	learn: -0.0166096	total: 1.92s	remaining: 1.92ms
# 999:	learn: -0.0165908	total: 1.92s	remaining: 0us
# Test error using softmax = 1.0
# total scores is  0.8
# done

# %% [markdown]
# #### 让我们来导入一下深度学习模型的训练数据

# %%
def deep_data_prepare():
    """

    :return:
    """
    train_x = []
    train_y = []
    ocr_train = []
    ocr_test = []
    test_x = []

    STOP_WORD = set()


    # 加载停用词
    with open(config.STOP_WORD_FILE, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            STOP_WORD.add(line)


    test_ids = []
    with open(config.TEST_FILE, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip().split('\t')
            test_ids.append(line[0])
            line = line[1].split(' ')
            tmp = []
            for l in line:
                if l == '' \
                        or l == ' ' \
                        or l in STOP_WORD\
                        or len(l) < 2:
                    continue


                if l in item_to_id:
                    id = item_to_id[l]
                    tmp.append(id)

            if len(tmp) == 0:
                tmp = [UNK]

            # 对于超过最大长度的我们只取前面的
            if len(tmp) > config.MAX_LEN:
                # print('Length Exceed!')
                tmp = tmp[:config.MAX_LEN]

            test_x.append(tmp)


    with open(config.TRAIN_X, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            line = line.split('\t')
            label = line[2]
            line = line[1].split(' ')
            tmp = []
            for l in line:
                if l == '' \
                        or l == ' ' \
                        or l in STOP_WORD\
                        or len(l) < 2:
                    continue


                if l in item_to_id:
                    id = item_to_id[l]
                    tmp.append(id)

            if len(tmp) == 0:
                tmp = [UNK]

            # 对于超过最大长度的我们只取前面的
            if len(tmp) > config.MAX_LEN:
                # print('Length Exceed!')
                tmp = tmp[:config.MAX_LEN]
            train_x.append(tmp)
            train_y.append(label)

            
    # 加载ocr模型数据
    
    with open(config.OCR_TRAIN_X, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip()
            line = line.split('\t')
            line = line[1].split(' ')
            tmp = []
            for l in line:
                if l == '' \
                        or l == ' ' \
                        or l in STOP_WORD\
                        or len(l) < 2:
                    continue


                if l in item_to_id:
                    id = item_to_id[l]
                    tmp.append(id)

            if len(tmp) == 0:
                tmp = [UNK]

            # 对于超过最大长度的我们只取前面的
            if len(tmp) > config.MAX_LEN:
                # print('Length Exceed!')
                tmp = tmp[:config.MAX_LEN]
            ocr_train.append(tmp)
            
    with open(config.OCR_TEST_X, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            line = line.strip().split('\t')
            test_ids.append(line[0])
            line = line[1].split(' ')
            tmp = []
            for l in line:
                if l == '' \
                        or l == ' ' \
                        or l in STOP_WORD\
                        or len(l) < 2:
                    continue


                if l in item_to_id:
                    id = item_to_id[l]
                    tmp.append(id)

            if len(tmp) == 0:
                tmp = [UNK]

            # 对于超过最大长度的我们只取前面的
            if len(tmp) > config.MAX_LEN:
                # print('Length Exceed!')
                tmp = tmp[:config.MAX_LEN]

            ocr_test.append(tmp)


    train_x = sequence.pad_sequences(train_x, maxlen=config.MAX_LEN, padding='post',
                                                         truncating='post', value=UNK)

    ocr_train = sequence.pad_sequences(ocr_train, maxlen=config.OCR_LEN, padding='post',
                                                         truncating='post', value=UNK)
    
    test_x = sequence.pad_sequences(test_x, maxlen=config.MAX_LEN, padding='post',
                                                         truncating='post', value=UNK)

    ocr_test = sequence.pad_sequences(ocr_test, maxlen=config.OCR_LEN, padding='post',
                                                         truncating='post', value=UNK)





    train_y = np_utils.to_categorical(train_y)
    print('train_x shape is: ', train_x.shape)
    print('train_y shape is: ', train_y.shape)

    test = {}
    test['news'] = test_x
    test['ocr'] = ocr_test

    train = {}
    train['news'] = train_x
    train['ocr'] = ocr_train
    return train, train_y, test

def init_embedding():
    print('vocabulary size : ', len(item_to_id) + 1)
    print('begin to load word2vec file')
    def get_coefs(word, *arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.rstrip().rsplit(' ')) for o in open(config.EMBEDDING_FILE))

    all_embs = np.stack(embeddings_index.values())
    emb_mean, emb_std = all_embs.mean(), all_embs.std()

    print('create embedding matrix')
    embedding_matrix = np.random.normal(emb_mean, emb_std, (len(item_to_id) + 1, config.EMBED_SIZES))
    for word, i in item_to_id.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: embedding_matrix[i] = embedding_vector
    print('end load word2vec')
    return embedding_matrix

# %%
data_x, data_y, test = deep_data_prepare()
init_emb = init_embedding()
# Out:
# train_x shape is:  (48480, 1000)
# train_y shape is:  (48480, 3)
# vocabulary size :  153325
# begin to load word2vec file
# create embedding matrix
# end load word2vec

# %% [markdown]
# #### 这里是导入深度学习模型，估计使用的模型可以参考config.py文件

# %%
model = config.model['model' + str(1)](config.MAX_LEN, config.OCR_LEN, (len(item_to_id) + 1), init_emb)

# %%
model.train_predict(data_x, data_y, test)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# news (InputLayer)               (None, 1000)         0
# __________________________________________________________________________________________________
# ocr (InputLayer)                (None, 400)          0
# __________________________________________________________________________________________________
# embedding (Embedding)           multiple             45997500    news[0][0]
#                                                                  ocr[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 1000, 300)    0           embedding[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 400, 300)     0           embedding[1][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 1000, 120)    129960      spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 400, 60)      59580       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 1000, 120)    65160       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 400, 60)      16380       bidirectional_3[0][0]
# __________________________________________________________________________________________________
# last (Lambda)                   (None, 120)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 120)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_1 (A (None, 120)          120         bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 120)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 60)           0           bidirectional_4[0][0]
# __________________________________________________________________________________________________
# attention_weighted_average_2 (A (None, 60)           60          bidirectional_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600)          0           last[0][0]
#                                                                  global_max_pooling1d_1[0][0]
#                                                                  attention_weighted_average_1[0][0
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_2[0][0]
#                                                                  attention_weighted_average_2[0][0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 600)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            1803        dropout_1[0][0]
# ==================================================================================================
# Total params: 46,270,563
# Trainable params: 273,063
# Non-trainable params: 45,997,500
# __________________________________________________________________________________________________
# Train on 36360 samples, validate on 12120 samples
# Epoch 1/6
#   192/36360 [..............................] - ETA: 50:09 - loss: 1.0754 - acc: 0.4427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9cf9a27c7039> in <module>()
# ----> 1 model.train_predict(data_x, data_y, test)
#
# ~/Desktop/SOHU_competition/src/model/model_basic.py in train_predict(self, train, train_y, test, option, true_length)
#     118                 self.model.summary()
#     119                 self.model.fit(kfold_X_train, y_train, batch_size=self.batch_size, epochs=6, verbose=1,
# --> 120                                validation_data=(kfold_X_valid, y_test))
#     121                 adam_optimizer = optimizers.Adam(lr=1e-4, clipvalue=1.5)
#     122
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
